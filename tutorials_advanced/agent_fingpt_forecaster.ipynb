# %% [markdown]
# # FinGPT-Forecaster Re-implemented with FinRobot

# %% [markdown]
# In this demo, we set up an agent to emulate the behavior of model in the fingpt-forecaster project with AutoGen, which takes a company's ticker symbol, recent basic financials and market news as input and predict its stock movements.
#
# For detail of the original project, check out  [FinGPT-Forecaster](https://github.com/AI4Finance-Foundation/FinGPT/tree/master/fingpt/FinGPT_Forecaster)!  🔥[Demo](https://huggingface.co/spaces/FinGPT/FinGPT-Forecaster), [Medium Blog](https://medium.datadriveninvestor.com/introducing-fingpt-forecaster-the-future-of-robo-advisory-services-50add34e3d3c) & [Model](https://huggingface.co/FinGPT/fingpt-forecaster_dow30_llama2-7b_lora) on Huggingface🤗!

# %%
import autogen
from autogen.cache import Cache

from finrobot.utils import get_current_date, register_keys_from_json
from finrobot.data_source import FinnHubUtils, YFinanceUtils

# %% [markdown]
# After importing all the necessary packages and functions, we first instantiate a market analysis assistant and a user proxy using the agent classes defined by AutoGen. We also need the config for OpenAI & Finnhub here.
# - for openai configuration, rename OAI_CONFIG_LIST_sample to OAI_CONFIG_LIST and replace the api keys
# - for finnhub configuration, rename config_api_keys_sample to config_api_keys and replace the api keys

# %%
# Read OpenAI API keys from a JSON file
config_list = autogen.config_list_from_json(
    "../OAI_CONFIG_LIST",
    # filter_dict={"model": ["gpt-4-0125-preview"]},
)
llm_config = {"config_list": config_list, "timeout": 120, "temperature": 0}

# Register FINNHUB API keys
register_keys_from_json("../config_api_keys")

# %%
analyst = autogen.AssistantAgent(
    name="Market_Analyst",
    system_message=" 作为一名市场分析师，必须具备较强的分析和解决问题的能力，收集所需的财务信息，并根据客户需求进行汇总。"
    "对于编程任务，只能使用你被提供的函数。任务完成后请回复 TERMINATE。",
    llm_config=llm_config,
)

user_proxy = autogen.UserProxyAgent(
    name="User_Proxy",
    is_termination_msg=lambda x: x.get("content", "") and x.get(
        "content", "").endswith("TERMINATE"),
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    code_execution_config={
        "work_dir": "coding",
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)

# %% [markdown]
# Then we register our predefined functions with the userproxy.
#
# Following our implementation with the fingpt-forecaster, we combined news/financials calls to the Finnhub API and stock data calls to the YFinance API.

# %%
from finrobot.toolkits import register_toolkits

tools = [
    {
        "function": FinnHubUtils.get_company_profile,
        "name": "get_company_profile",
        "description": "get a company's profile information"
    },
    {
        "function": FinnHubUtils.get_company_news,
        "name": "get_company_news",
        "description": "retrieve market news related to designated company"
    },
    {
        "function": FinnHubUtils.get_basic_financials,
        "name": "get_financial_basics",
        "description": "get latest financial basics for a designated company"
    },
    {
        "function": YFinanceUtils.get_stock_data,
        "name": "get_stock_data",
        "description": "retrieve stock price data for designated ticker symbol"
    }
]
register_toolkits(tools, 
                  caller = analyst, # The assistant agent can suggest calls to the calculator.
                  executor = user_proxy # The user proxy agent can execute the calculator calls.
                  )

# %% [markdown]
# Start the conversation, asking the agent to call all the functions, and see how it aggregates all the information and leads to the conclusion.

# %%
# company = "Tesla"
company = "APPLE"

with Cache.disk() as cache:
    # start the conversation
    user_proxy.initiate_chat(
        analyst,
        message=f"请使用所有可用工具，获取截至 {get_current_date()} 为止关于 {company} 的信息。请分析 {company} 的积极发展动态和潜在风险问题，"
        "分别列出 2-4 个最重要的因素，并保持简明扼要。多数因素应从公司相关新闻中推断得出。"
        f"然后对 {company} 的股价在下周的走势做出一个粗略预测（例如上涨/下跌 2-3%）。请提供一份总结分析来支持你的预测。",
        cache=cache,
    )
# Out:
# User_Proxy (to Market_Analyst):
#
# 请使用所有可用工具，获取截至 2025-06-02 为止关于 APPLE 的信息。请分析 APPLE 的积极发展动态和潜在风险问题，分别列出 2-4 个最重要的因素，并保持简明扼要。多数因素应从公司相关新闻中推断得出。然后对 APPLE 的股价在下周的走势做出一个粗略预测（例如上涨/下跌 2-3%）。请提供一份总结分析来支持你的预测。
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 06-02 11:49:15] {696} WARNING - Model qwen-turbo-2025-02-11 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Market_Analyst (to User_Proxy):
#
#
# ***** Suggested tool call (call_7ef0b59464d748efae7262): get_company_news *****
# Arguments:
# {"symbol": "AAPL", "start_date": "2025-05-01", "end_date": "2025-06-02", "max_news_num": 10}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_company_news...
# Call ID: call_7ef0b59464d748efae7262
# Input arguments: {'symbol': 'AAPL', 'start_date': '2025-05-01', 'end_date': '2025-06-02', 'max_news_num': 10}
# Finnhub client initialized
# User_Proxy (to Market_Analyst):
#
# ***** Response from calling tool (call_7ef0b59464d748efae7262) *****
#              date                                                                                   headline                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               summary
# 0  20250524170000                   Charting the Global Economy: Long-Term Bond Yields Soar Around the World  (Bloomberg) -- Around the world, yields on longer-dated sovereign debt have soared as investors question the ability of governments to cover massive budget deficits.Most Read from BloombergNY Private School Pleads for Donors to Stay Open After Declaring BankruptcyUAE’s AI University Aims to Become Stanford of the GulfNYC’s War on Trash Gets a Glam SquadCan Frank Gehry’s ‘Grand LA’ Make Downtown Feel Like a Neighborhood?Chicago’s O’Hare Airport Seeks Up to $4.3 Billion of Muni DebtIn the US, 30-y
# 1  20250525110000                               Tech Stocks Had a Crazy Few Days. Another Big Week Is Ahead.                                                                                                                                                                                                                                                                                                                                                                                                                                                          Tech Stocks Had a Crazy Few Days. Another Big Week Is Ahead.
# 2  20250525220000               Trump’s New Tariffs, Nvidia, Salesforce, Costco, and More to Watch This Week                                                                                                                                                                                                                                                                                                                                                                                                                                          Trump’s New Tariffs, Nvidia, Salesforce, Costco, and More to Watch This Week
# 3  20250527103000                 The London Company Income Equity Vs. Russell 1000 Value Q1 2025 Commentary                                                                                                                                                                                                                                                                                                                                                                                      The London Company Income Equity portfolio returned 4.6% during the quarter vs. a 2.1% increase in the Russell 1000 Value Index.
# 4  20250527144800         There’s a New Trump Tariff Trade Set to Overshadow Nvidia Earnings, Inflation Data                                                                                                                                                                                                                                                                                                                                                                                                                                    There’s a New Trump Tariff Trade Set to Overshadow Nvidia Earnings, Inflation Data
# 5  20250527195016            Trump Targets Apple iPhones Again, But This Tariff Panic Won't Stick - Buy Call
# 6  20250528034015                      Apple to Debut Dedicated Gaming App Within Days of Switch 2’s Arrival  (Bloomberg) -- Apple Inc. is planning a dedicated app for video games on its devices, seeking to sell gamers and developers on the idea that it’s a leader in the market.Most Read from BloombergUAE’s AI University Aims to Become Stanford of the GulfNY Wins Order Against US Funding Freeze in Congestion FightThe company will preinstall the app on the iPhone, iPad, Mac and Apple TV set-top box later this year, according to people with knowledge of the matter. The software will serve as a launcher fo
# 7  20250529171500                                  Apple's Perfect Storm: Tariffs, China, AI, And Innovation                                                                                                                                                                                                                                                                                                                                                                                                              Explore the challenges Apple faces: tariffs, political risks, declining China sales, and slow AI growth.
# 8  20250530114500                                                          Generation PMCA Q1 2025 Quarterly
# 9  20250531170000  Shimmers, floating toolbars, and radical transparency: Here’s what iOS 26 could look like                                                                                                                                                                                                                                                                                                                                                                                                 Apple needs something eye-catching right now. A new user interface, likely called ‘solarium,’ is about to turn heads.
# ********************************************************************
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 06-02 11:49:25] {696} WARNING - Model qwen-turbo-2025-02-11 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Market_Analyst (to User_Proxy):
#
# ### 苹果公司的积极发展动态与潜在风险问题
#
# #### 积极发展动态：
# 1. **苹果计划推出专用游戏应用**
#    根据新闻报道，苹果正在开发一款专门的游戏应用程序，该应用将在iPhone、iPad、Mac以及Apple TV上预装。这表明苹果正试图扩大其在视频游戏领域的影响力，可能吸引更多游戏玩家和开发者。这一举措可能增强苹果的生态系统，并推动其硬件和服务收入的增长。
#
# 2. **iOS 26的新功能**
#    有传言称iOS 26将引入一些令人瞩目的新功能，如“太阳能”界面设计。这些新功能可能会提升用户体验，进一步巩固苹果在消费者心中的品牌形象。
#
# #### 潜在风险问题：
# 1. **中美贸易战与关税政策**
#    特朗普政府再次将苹果产品列入加征关税的清单，这对苹果的供应链和盈利能力构成了威胁。如果苹果不能迅速调整供应链或提高产品价格，这可能对其销售和利润产生负面影响。
#
# 2. **中国市场的挑战**
#    新闻提到苹果在中国市场的销售额有所下降。由于中国市场的重要性，这种趋势可能会影响苹果的整体营收增长。
#
# ### 股价预测
# 综合以上因素，我认为苹果的股价在下周可能会小幅下跌约2-3%。原因如下：
# - 游戏应用的推出虽然是一个积极信号，但短期内可能无法显著影响股价。
# - 关税政策和中国市场挑战可能引发投资者担忧，从而导致短期抛售压力增加。
# - iOS 26的新功能虽然令人期待，但尚未明确对用户吸引力的具体程度。
#
# 总结来说，尽管苹果有一些积极的发展动态，但当前的外部环境（如关税和中国市场表现）可能对股价造成一定的下行压力。因此，预计苹果股价在下周将出现小幅下跌。
#
# --------------------------------------------------------------------------------
# User_Proxy (to Market_Analyst):
#
#
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 06-02 11:49:27] {696} WARNING - Model qwen-turbo-2025-02-11 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Market_Analyst (to User_Proxy):
#
#
# ***** Suggested tool call (call_c8e8dff807d7402ea2c7ce): get_financial_basics *****
# Arguments:
# {"symbol": "AAPL"}
# ***********************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_financial_basics...
# Call ID: call_c8e8dff807d7402ea2c7ce
# Input arguments: {'symbol': 'AAPL'}
# Finnhub client initialized
# User_Proxy (to Market_Analyst):
#
# ***** Response from calling tool (call_c8e8dff807d7402ea2c7ce) *****
# {
#   "10DayAverageTradingVolume": 55.16882,
#   "13WeekPriceReturnDaily": -15.3603,
#   "26WeekPriceReturnDaily": -12.2926,
#   "3MonthADReturnStd": 51.084312,
#   "3MonthAverageTradingVolume": 59.25201,
#   "52WeekHigh": 260.1,
#   "52WeekHighDate": "2024-12-26",
#   "52WeekLow": 169.2101,
#   "52WeekLowDate": "2025-04-08",
#   "52WeekPriceReturnDaily": 5.5494,
#   "5DayPriceReturnDaily": 2.8576,
#   "assetTurnoverAnnual": 1.0714,
#   "assetTurnoverTTM": 1.1673,
#   "beta": 1.2146548,
#   "bookValuePerShareAnnual": 3.7673,
#   "bookValuePerShareQuarterly": 4.4712,
#   "bookValueShareGrowth5Y": -5.85,
#   "capexCagr5Y": -2.08,
#   "cashFlowPerShareAnnual": 7.1978,
#   "cashFlowPerShareQuarterly": 6.5924,
#   "cashFlowPerShareTTM": 6.86253,
#   "cashPerSharePerShareAnnual": 4.3112,
#   "cashPerSharePerShareQuarterly": 3.2463,
#   "currentDividendYieldTTM": 0.5105,
#   "currentEv/freeCashFlowAnnual": 28.214,
#   "currentEv/freeCashFlowTTM": 31.1708,
#   "currentRatioAnnual": 0.8673,
#   "currentRatioQuarterly": 0.8209,
#   "dividendGrowthRate5Y": 5.3,
#   "dividendPerShareAnnual": 0.9935,
#   "dividendPerShareTTM": 1.0115,
#   "dividendYieldIndicatedAnnual": 0.5177993,
#   "ebitdPerShareAnnual": 8.7571,
#   "ebitdPerShareTTM": 9.1121,
#   "ebitdaCagr5Y": 11.9,
#   "ebitdaInterimCagr5Y": 15.39,
#   "enterpriseValue": 3069884.8,
#   "epsAnnual": 6.0836,
#   "epsBasicExclExtraItemsAnnual": 6.0836,
#   "epsBasicExclExtraItemsTTM": 6.4078,
#   "epsExclExtraItemsAnnual": 6.0836,
#   "epsExclExtraItemsTTM": 6.4078,
#   "epsGrowth3Y": 2.71,
#   "epsGrowth5Y": 15.41,
#   "epsGrowthQuarterlyYoy": 7.68,
#   "epsGrowthTTMYoy": -0.36,
#   "epsInclExtraItemsAnnual": 6.0836,
#   "epsInclExtraItemsTTM": 6.4078,
#   "epsNormalizedAnnual": 6.0836,
#   "epsTTM": 6.4078,
#   "focfCagr5Y": 13.06,
#   "grossMargin5Y": 42.73,
#   "grossMarginAnnual": 46.21,
#   "grossMarginTTM": 46.63,
#   "inventoryTurnoverAnnual": 30.8955,
#   "inventoryTurnoverTTM": 34.184,
#   "longTermDebt/equityAnnual": 1.5057,
#   "longTermDebt/equityQuarterly": 1.1762,
#   "marketCapitalization": 2999860.8,
#   "monthToDatePriceReturnDaily": -5.4824,
#   "netIncomeEmployeeAnnual": 0.5716,
#   "netIncomeEmployeeTTM": 0.5933,
#   "netInterestCoverageAnnual": 622.5082,
#   "netInterestCoverageTTM": 622.5082,
#   "netMarginGrowth5Y": 2.45,
#   "netProfitMargin5Y": 24.28,
#   "netProfitMarginAnnual": 23.97,
#   "netProfitMarginTTM": 24.3,
#   "operatingMargin5Y": 29.11,
#   "operatingMarginAnnual": 31.51,
#   "operatingMarginTTM": 31.81,
#   "payoutRatioAnnual": 16.25,
#   "payoutRatioTTM": 0.1574,
#   "pb": 50.0084,
#   "pbAnnual": 61.8474,
#   "pbQuarterly": 50.0084,
#   "pcfShareAnnual": 25.3679,
#   "pcfShareTTM": 27.382,
#   "peAnnual": 32.0033,
#   "peBasicExclExtraTTM": 30.8329,
#   "peExclExtraAnnual": 30.96975,
#   "peExclExtraTTM": 30.8329,
#   "peInclExtraTTM": 30.8329,
#   "peNormalizedAnnual": 32.0033,
#   "peTTM": 34.3327,
#   "pfcfShareAnnual": 27.5705,
#   "pfcfShareTTM": 30.4598,
#   "pretaxMargin5Y": 29.15,
#   "pretaxMarginAnnual": 31.58,
#   "pretaxMarginTTM": 31.72,
#   "priceRelativeToS&P50013Week": -16.1021,
#   "priceRelativeToS&P50026Week": -12.1046,
#   "priceRelativeToS&P5004Week": -6.1843,
#   "priceRelativeToS&P50052Week": -6.4806,
#   "priceRelativeToS&P500Ytd": -20.3595,
#   "psAnnual": 7.6716,
#   "psTTM": 8.3433,
#   "ptbvAnnual": 4.8643,
#   "ptbvQuarterly": 6.4066,
#   "quickRatioAnnual": 0.826,
#   "quickRatioQuarterly": 0.7775,
#   "receivablesTurnoverAnnual": 12.43,
#   "receivablesTurnoverTTM": 16.6913,
#   "revenueEmployeeAnnual": 2.3844,
#   "revenueEmployeeTTM": 2.4413,
#   "revenueGrowth3Y": 2.25,
#   "revenueGrowth5Y": 8.49,
#   "revenueGrowthQuarterlyYoy": 5.08,
#   "revenueGrowthTTMYoy": 4.91,
#   "revenuePerShareAnnual": 25.3785,
#   "revenuePerShareTTM": 26.5916,
#   "revenueShareGrowth5Y": 12.65,
#   "roa5Y": 25.24,
#   "roaRfy": 25.679999999999996,
#   "roaTTM": 0.2837,
#   "roe5Y": 151.11,
#   "roeRfy": 164.59,
#   "roeTTM": 1.5131,
#   "roi5Y": 50.63,
#   "roiAnnual": 56.989999999999995,
#   "roiTTM": 58.95,
#   "tangibleBookValuePerShareAnnual": 5.8583,
#   "tangibleBookValuePerShareQuarterly": 6.7916,
#   "tbvCagr5Y": 11.34,
#   "totalDebt/totalEquityAnnual": 1.8881,
#   "totalDebt/totalEquityQuarterly": 1.4699,
#   "yearToDatePriceReturnDaily": -19.7947,
#   "bookValue": 66796,
#   "cashRatio": 0.19479702014926922,
#   "currentRatio": 0.8209,
#   "ebitPerShare": 1.9652,
#   "eps": 1.6458,
#   "ev": 3410387,
#   "fcfMargin": 0.219,
#   "fcfPerShareTTM": 6.5924,
#   "grossMargin": 0.4705,
#   "longtermDebtTotalAsset": 0.2372,
#   "longtermDebtTotalCapital": 0.4762,
#   "longtermDebtTotalEquity": 1.1762,
#   "netDebtToTotalCapital": 0.4244,
#   "netDebtToTotalEquity": 1.0483,
#   "netMargin": 0.2599,
#   "operatingMargin": 0.3103,
#   "pfcfTTM": 33.9171,
#   "pretaxMargin": 0.3074,
#   "ptbv": 6.4066,
#   "quickRatio": 0.7775,
#   "roicTTM": 0.5895,
#   "rotcTTM": 0.7718,
#   "salesPerShare": 6.3336,
#   "sgaToSale": 0.5295,
#   "tangibleBookValue": 138050,
#   "totalDebtToEquity": 1.4699,
#   "totalDebtToTotalAsset": 0.2964,
#   "totalDebtToTotalCapital": 0.5951,
#   "totalRatio": 1.2526
# }
# ********************************************************************
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 06-02 11:49:36] {696} WARNING - Model qwen-turbo-2025-02-11 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Market_Analyst (to User_Proxy):
#
# ### 分析与预测总结
#
# #### 公司概况与财务数据
# 根据最新的财务数据，苹果公司（AAPL）的市盈率（PE TTM）为34.33倍，表明投资者对公司未来收益增长抱有一定期望。然而，每股收益（EPS TTM）为6.41美元，较去年同期略有下降（-0.36%），显示出公司在盈利方面面临一定压力。
#
# 此外，苹果的流动比率（Current Ratio）为0.82，低于行业平均水平，这可能暗示公司在短期内偿还债务的能力有限。同时，速动比率（Quick Ratio）更低，仅为0.78，进一步强调了流动性风险。
#
# #### 新闻动态分析
# 从新闻中可以看出，苹果近期面临一些挑战，包括中美贸易战带来的关税压力以及中国市场的销售下滑。此外，苹果计划推出的游戏应用和iOS 26的新功能可能为其带来新的增长点，但这些措施需要时间才能显现效果。
#
# #### 股价预测
# 结合新闻动态和财务数据，我认为苹果的股价在下周可能会继续呈现小幅波动，预计下跌约2-3%。主要原因包括：
# - 关税政策和中国市场挑战可能导致短期投资者信心不足。
# - 财务数据显示盈利增长放缓，可能抑制股价上涨。
#
# 总结来看，尽管苹果有潜力通过新产品和服务实现长期增长，但当前的外部环境和财务指标表明短期内股价可能承压。因此，建议投资者密切关注后续财报和市场动态，以便及时调整投资策略。 TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (275f8bc1-8a01-4289-9fe8-ce0789399310): Termination message condition on agent 'User_Proxy' met

# %% [markdown]
# ## Data
#
# ### 1. `finnhub_utils`
#
# Finnhub 提供的主要数据和服务包括：实时和历史市场数据、公司基本面数据、另类数据、技术分析数据、其他数据（全球 ETF、共同基金和指数数据、经济数据、美国债券数据）

# %% [markdown]
# #### `get_company_profile`
#
# `formatted_str = (...) .format(**profile)`: 如果获取成功，它会将返回的 profile 字典中的数据填充到一个预设的格式化字符串模板中，生成一段易于阅读的公司介绍。

# %%
FinnHubUtils.get_company_profile("AAPL")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 FinnHubUtils.get_company_profile("AAPL")
#
# NameError: name 'FinnHubUtils' is not defined

# %%
finnhub_client = finnhub.Client(api_key=os.environ["FINNHUB_API_KEY"])
finnhub_client.company_profile2(symbol="AAPL")
# Out:
# {'country': 'US',
#  'currency': 'USD',
#  'estimateCurrency': 'USD',
#  'exchange': 'NASDAQ NMS - GLOBAL MARKET',
#  'finnhubIndustry': 'Technology',
#  'ipo': '1980-12-12',
#  'logo': 'https://static2.finnhub.io/file/publicdatany/finnhubimage/stock_logo/AAPL.png',
#  'marketCapitalization': 2999860.6408355245,
#  'name': 'Apple Inc',
#  'phone': '14089961010',
#  'shareOutstanding': 14935.83,
#  'ticker': 'AAPL',
#  'weburl': 'https://www.apple.com/'}

# %% [markdown]
# #### `get_company_news(...)`
#
# 检索与指定公司相关的市场新闻。（默认10条）
#
# - 调用 `finnhub_client` 的 `company_news` 方法获取指定日期范围内的公司新闻。
#
# - **对新闻数据进行处理：将时间戳 (`n["datetime"]`) 转换为 "YYYYMMDDHHMMSS" 格式的日期字符串，并提取标题 (`headline`) 和摘要 (`summary`)。**
#
# - **如果获取到的新闻数量超过 max_news_num，则随机选择 max_news_num 条新闻。**
# - **news.sort(key=lambda x: x["date"]): 按日期对新闻进行排序。**
# - output = pd.DataFrame(news)

# %%
FinnHubUtils.get_company_news(
    symbol = "AAPL", 
    start_date = "2025-05-01", 
    end_date = "2025-06-02", 
    max_news_num = 10,
    save_path = "./AAPL_news.csv"
)
# Out:
# Finnhub client initialized
# company news of AAPL saved to ./AAPL_news.csv
#              date                                           headline  \
# 0  20250524044100  Stocks Fall on Tariff Broadside, After Week of...
# 1  20250524045602  Trump Targets Samsung, Apple Phones With 25% T...
# 2  20250526081908    Trump says US wants to make tanks, not T-shirts
# 3  20250527000000  How To Build A $100,000 Dividend Portfolio Tha...
# 4  20250527182700  As Trump hits E.U., phone makers with fresh th...
# 5  20250528041500            EU Crisis Averted. Same Time Next Week?
# 6  20250528045846               iPhone Tariff Threat Weighs on Apple
# 7  20250528233406                      Apple to Debut New Gaming App
# 8  20250529043030  Trump's Apple Beef Isn't Just About India-Made...
# 9  20250530120305  Texas passes law requiring age verification in...
#
#                                              summary
# 0  President Trump renewed his tariff campaign Fr...
# 1  (Bloomberg) -- Supply Lines is a daily newslet...
# 2  U.S.President Donald Trump said on Sunday his ...
# 3  The Dividend Income Accelerator Portfolio targ...
# 4  As Trump hits E.U., phone makers with fresh th...
# 5  Wall Street sprinted back from last weekâs s...
# 6  It's a "fairytale" to think the full iPhone su...
# 7  Apple plans to launch a new gaming app at its ...
# 8  Apple Inc. (NASDAQ:AAPL) CEO Tim Cook has foun...
# 9  Copyright © BusinessAMBE 2023Key takeawaysTexa...

# %%
news = finnhub_client.company_news("AAPL", _from="2025-05-01", to="2025-06-02")

print(len(news))

news
# Out:
# 235
# [{'category': 'company',
#   'datetime': 1748824690,
#   'headline': 'Apple To Appeal EU Requirement To Share Info With Tech Rivals- Axios',
#   'id': 134930923,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': 'June 2 - * APPLE TO APPEAL EU REQUIREMENT TO SHARE INFO WITH TECHRIVALS-AXIOSSource text: https://tinyurl.com/yk8cndedFurther company coverage: ...',
#   'url': 'https://finnhub.io/api/news?id=19519f0fe4a1f4f328a62c14512d61f82a3a951a6895f4e2923cb61024814bee'},
#  {'category': 'company',
#   'datetime': 1748822803,
#   'headline': 'Stock market today: Dow, S&P 500, Nasdaq futures slip as Wall Street kicks off June after bullish May',
#   'id': 134929798,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'US stock futures edged lower Sunday evening, following a bullish May driven by tech optimism and resilient economic data.',
#   'url': 'https://finnhub.io/api/news?id=fe9602b152d802e9822382e47917b4b871bda2a032950609a688e3c71c39e6d8'},
#  {'category': 'company',
#   'datetime': 1748818800,
#   'headline': 'Samsung Nears Wide-Ranging Deal With Perplexity for AI Features',
#   'id': 134930346,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- Samsung Electronics Co. is nearing a wide-ranging deal to invest in Perplexity AI Inc. and put search technology from the artificial intelligence startup at the forefront of the South Korean company’s devices. Most Read from BloombergBillionaire Steve Cohen Wants NY to Expand Taxpayer-Backed FerryWhere the Wild Children’s Museums AreThe Economic Benefits of Paying Workers to MoveNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaNYC Congestion Toll Brings In $',
#   'url': 'https://finnhub.io/api/news?id=aeda7ae9270f744876909b61c1b4f04ff558e970b726db4025676c336a32da23'},
#  {'category': 'company',
#   'datetime': 1748817600,
#   'headline': 'Madison Diversified Income Fund Q1 2025 Investment Strategy Letter',
#   'id': 134930488,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1360551449/image_1360551449.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'Madison Diversified Income Fund was well positioned for the quarterâ\x80\x99s market volatility via a relative underweight to stocks against its long-term 50% portfolio target.',
#   'url': 'https://finnhub.io/api/news?id=5252f08a9224f0116f37e9823f42fbefe189c7642d622e6e433c49c9ae9f32f2'},
#  {'category': 'company',
#   'datetime': 1748816100,
#   'headline': 'Apple Stock: Did President Trump Just Give Investors a Reason to Sell?',
#   'id': 134930347,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'President Trump wants iPhones assembled in the United States, which would be expensive for Apple.  Apple (NASDAQ: AAPL) has optimized its costs through a global manufacturing footprint.  This relationship -- specifically with China -- may be coming to an end if President Donald Trump gets his way.',
#   'url': 'https://finnhub.io/api/news?id=d0862599ff8534538498a2ba75d6e5f9cb2bfcc6d4e6ede5e71b10d7a4f1f694'},
#  {'category': 'company',
#   'datetime': 1748806769,
#   'headline': "Tracking Mario Gabelli's Gabelli Funds 13F Portfolio - Q1 2025 Update",
#   'id': 134929675,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/186805810/image_186805810.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': "Discover Gabelli Funds' Q1 2025 portfolio updates: $13.12B value, top holdings, disciplined profit-taking, and a broad, risk-managed investment strategy.",
#   'url': 'https://finnhub.io/api/news?id=2025f666130384a11306f56e9930a8a85f8b85329a8ff5218858d081f3d4ea58'},
#  {'category': 'company',
#   'datetime': 1748790000,
#   'headline': 'Big Tech Is Back in S&P 500 Driver’s Seat as Profit Engines Hum',
#   'id': 134927980,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- The same technology giants that helped drag the S&P 500 to the brink of a bear market in April are giving the recovery in US equities some legs.Most Read from BloombergBillionaire Steve Cohen Wants NY to Expand Taxpayer-Backed FerryWhere the Wild Children’s Museums AreNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaThe Economic Benefits of Paying Workers to MoveNYC Congestion Toll Brings In $216 Million in First Four MonthsNvidia Corp. put a bow on a better',
#   'url': 'https://finnhub.io/api/news?id=cf21208226102bc4d148436f243140ed71a72853537824f37e9c557040154686'},
#  {'category': 'company',
#   'datetime': 1748777640,
#   'headline': 'Madison Asset Allocation Funds Q1 2025 Investment Strategy Letter',
#   'id': 134927993,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/2153980329/image_2153980329.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'The index decline was as narrow as its prior advance and outside of the Mag-7 world, seven of the eleven S&P sectors provided positive returns. Read more here.',
#   'url': 'https://finnhub.io/api/news?id=883499586a47f94a252406f57c1f19f4349198de942346c17470b9d0de3c2675'},
#  {'category': 'company',
#   'datetime': 1748772102,
#   'headline': 'Pomerantz Law Firm Investigates Claims On Behalf of Investors of Apple Inc. - AAPL',
#   'id': 134927588,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': 'NEW YORK, June 1, 2025 /PRNewswire/ -- Pomerantz LLP is investigating claims on behalf of investors of\xa0Apple Inc.\xa0\xa0. Such investors are advised to contact Danielle\xa0Peyton at...',
#   'url': 'https://finnhub.io/api/news?id=3616a95a03881333d2410c6103ab5d6e233d2614bc3f8d185ceaa389c8b60137'},
#  {'category': 'company',
#   'datetime': 1748770800,
#   'headline': 'Will Apple Reclaim Its Title as the Largest Company in the World by Market Cap? The Answer May Surprise You.',
#   'id': 134927198,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Apple was the largest company by market cap for more than a decade but recently was dethroned by Microsoft and Nvidia.  The company is growing sales much slower than Nvidia or Microsoft.  Apple's slow growth and risks to its earnings mean it will likely not regain its market cap leadership position.",
#   'url': 'https://finnhub.io/api/news?id=c259136d64fc086c140117373179518d2ccdd6641e484c1cb1b55ce6abc77b4a'},
#  {'category': 'company',
#   'datetime': 1748770200,
#   'headline': 'Taser Boss Tops Ranking of Highest-Paid CEOs, With $165 Million. Here’s the List.',
#   'id': 134927199,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'A stock award propelled Rick Smith past Apple’s Tim Cook and Blackstone’s Schwarzman to the top of WSJ’s annual ranking.',
#   'url': 'https://finnhub.io/api/news?id=d4889fe5b39bf46b7338468210585418d03d79f21453e375c7b80433e9ceaec4'},
#  {'category': 'company',
#   'datetime': 1748766600,
#   'headline': 'How The BLSH Portfolio Buys Low And Sells High, Consistently',
#   'id': 134927246,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/536134845/image_536134845.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'The BLSH strategy systematically buys blue-chip stocks at undervalued prices and sells partial positions at overvalued levels. Learn more about the strategy here.',
#   'url': 'https://finnhub.io/api/news?id=da9f4c876d8f46ad218f622289f0a249ade8eac2f56f6ee313e2293c6632ad29'},
#  {'category': 'company',
#   'datetime': 1748700000,
#   'headline': 'Best Stock to Buy Right Now: Apple vs. Chipotle',
#   'id': 134918751,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Chipotle has had more consistent annual growth rates than Apple.  Meanwhile, Apple is currently right in the crosshairs of more tariffs.  The clearer path for future growth at Chipotle makes it more appealing.',
#   'url': 'https://finnhub.io/api/news?id=4501b08fa57a0992a1ab58af2d22016d5d8c28c1075ae18d663a2f42c568c08d'},
#  {'category': 'company',
#   'datetime': 1748692807,
#   'headline': 'Where the Stock Market Stands Now After a Wild Start to the Year',
#   'id': 134918506,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- The stock market’s crazy first five months of 2025 have left Wall Street pros in a bit of a pickle. Most Read from BloombergBillionaire Steve Cohen Wants NY to Expand Taxpayer-Backed FerryNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaNYC Congestion Toll Brings In $216 Million in First Four MonthsThe Economic Benefits of Paying Workers to MoveWhere the Wild Children’s Museums AreComing off the best month for the S&P 500 Index in a year and a half and the b',
#   'url': 'https://finnhub.io/api/news?id=627480b3dc41e957bc55d7f2abf0d70d50f0344b5d440b54d36dc453a4484076'},
#  {'category': 'company',
#   'datetime': 1748691000,
#   'headline': "47% of Berkshire Hathaway's $276 Billion Warren Buffett-Led Portfolio Is Invested in 3 Dividend Stocks",
#   'id': 134918267,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Apple has developed an ecosystem of tech devices that its customers love and are willing to trade up to have.  American Express has numerous earnings streams, and a younger cohort of cardholders is driving growth.  Coca-Cola's business has proven resilient under pressure, and it reliably boosts its dividends.",
#   'url': 'https://finnhub.io/api/news?id=c4de5351dcac4420cc10d76e35d0975c0480d983513d922632b0a43644c7f310'},
#  {'category': 'company',
#   'datetime': 1748689200,
#   'headline': 'These Are Stocks You Should Watch in June',
#   'id': 134917808,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Stocks soared in May, boosted by easing trade tensions, solid corporate earnings and signs of economic resilience. Trade and tax policy are likely to remain Wall Street's focus in June.",
#   'url': 'https://finnhub.io/api/news?id=a6169a1e7ec907c72deaa014071f49bd0c2c243b18165b12c9bb50dd0e088a0b'},
#  {'category': 'company',
#   'datetime': 1748682000,
#   'headline': 'Shimmers, floating toolbars, and radical transparency: Here’s what iOS 26 could look like',
#   'id': 134930573,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple needs something eye-catching right now. A new user interface, likely called ‘solarium,’ is about to turn heads.',
#   'url': 'https://finnhub.io/api/news?id=a29b5ab8f1ff1d6538afe02271da97a011e4aba7819b21b54b7b621d0917acbe'},
#  {'category': 'company',
#   'datetime': 1748680800,
#   'headline': 'Warren Buffett Holds Apple Stock Despite Tariffs and Buys a Restaurant Stock Up 4,500% in 15 Years',
#   'id': 134918975,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Warren Buffett's Berkshire Hathaway continued to hold Apple and added to its stake in Domino’s Pizza in the first quarter.  Apple stock looks expensive with earnings increasing just 8% in the second quarter, and tariffs could slow profit growth even further.  Warren Buffett manages the vast majority of Berkshire Hathaway's stock portfolio, and the company made interesting capital allocation decisions concerning Apple (NASDAQ: AAPL) and Domino's Pizza (NASDAQ: DPZ) in the first quarter.",
#   'url': 'https://finnhub.io/api/news?id=e015ab59f6f96c5e37b4978a2909af5ab4f67697ccb9767821ff4ba660a44172'},
#  {'category': 'company',
#   'datetime': 1748678404,
#   'headline': 'Trump’s trade war is bruising Apple — and your 401(k)',
#   'id': 134917836,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'President Donald Trump’s swipes at Apple aren’t just bruising the company’s bottom line — they may also be taking a bite out of your 401(k).',
#   'url': 'https://finnhub.io/api/news?id=d5d2117a126dfc081258b714482c6358035e84c9272d7c2ab5416d9e7d89f321'},
#  {'category': 'company',
#   'datetime': 1748640917,
#   'headline': 'Judge Weighs Big Changes to Google, Including Breakup, AI Limits',
#   'id': 134908346,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- The federal judge who will decide how to limit Google’s monopoly in search is considering its advantage in artificial intelligence, and aiming to minimize harm to the other players in the market with any resolution. Most Read from BloombergNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaBillionaire Steve Cohen Wants NY to Expand Taxpayer-Backed FerryNYC Congestion Toll Brings In $216 Million in First Four MonthsThe Economic Benefits of Paying Workers to Mov',
#   'url': 'https://finnhub.io/api/news?id=f56a5e9b02c19c815944e83dac9bb51bd35e77d7df14693d76dbbfde2a1bd223'},
#  {'category': 'company',
#   'datetime': 1748638739,
#   'headline': "US Smartphone Manufacturing Is a 'Dream': IDC's Popal",
#   'id': 134908381,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Smartphone manufacturing in the US is a "dream," says Nabila Popal, IDC senior research director. She discusses her research with Ed Ludlow on "Bloomberg Technology."',
#   'url': 'https://finnhub.io/api/news?id=06e130ae4ed075c18cf859b87de11d192724585fba088f1631887e3a699d0410'},
#  {'category': 'company',
#   'datetime': 1748637878,
#   'headline': "Elon Musk's renewed 'laser focus' on Tesla is his 'redemption arc'",
#   'id': 134908382,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Elon Musk is back at Tesla (TSLA) after serving as a special government employee leading US President Trump's Department of Government Efficiency (DOGE). Intelligent Alpha founder and CEO Doug Clinton joins Market Domination with Josh Lipton, Josh Schafer, and Macro Talk News founder Hope King to compare Musk's place at Tesla with the other innovative drives seen from other historic tech executives. To watch more expert insights and analysis on the latest market action, check out more Market Domination here.",
#   'url': 'https://finnhub.io/api/news?id=1e8a27343835640d04cc22e490d4463bd879aa34e2d53e48e622c1feb5069441'},
#  {'category': 'company',
#   'datetime': 1748633690,
#   'headline': 'Apple Rebound Likely as Court Blocks Tariff Sell-Off Catalyst',
#   'id': 134908383,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Court Blocks Trump Tariffs, Apple Set to Surge from Sell-Off',
#   'url': 'https://finnhub.io/api/news?id=44e3c071b64b8afefbc2833865afe217bcc558afb6028e5a8fc9bb9c5902965d'},
#  {'category': 'company',
#   'datetime': 1748631930,
#   'headline': "The fate of Google's search empire is now up to a judge",
#   'id': 134908384,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Google will have to wait for a US judge to decide if the company should be forced to sell off its Chrome browser.',
#   'url': 'https://finnhub.io/api/news?id=0cba09f8d007fbb9d385ca539936ebab31bb3d8651d68cbfb253b1d041884a29'},
#  {'category': 'company',
#   'datetime': 1748628734,
#   'headline': 'Apple: China Sales Collapse Is Only Getting Worse',
#   'id': 134908102,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1742571433/image_1742571433.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': "Apple Inc.'s challenges in China grow with declining sales and rising supply chain risk. Click for how AAPL's services remains a bright spot in a gloomy picture.",
#   'url': 'https://finnhub.io/api/news?id=e5bdcdbe14050a438664ea3fc5c5749d7bdea18c87b2c16a77b2d63c3097d8af'},
#  {'category': 'company',
#   'datetime': 1748617320,
#   'headline': '4 Dividend-Paying Dow Jones Growth Stocks to Buy in June and Hold for Decades',
#   'id': 134908353,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple could be heavily impacted by tariffs, but the long-term investment thesis is sound.  Microsoft continues to fire on all cylinders and deserves to be near an all-time high.  Visa and American Express benefit from network effects that help them steadily grow over time.',
#   'url': 'https://finnhub.io/api/news?id=a6a0e1c5c7d6d606cb8a3a2c9c0e11d3ca0c1a2d42b65ddffdf2accf6971618b'},
#  {'category': 'company',
#   'datetime': 1748616069,
#   'headline': 'Apple Sees Small Rebound in China Shipments',
#   'id': 134904032,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Foreign-branded phone volume rises to 3.52 million units in April, up 0.6% y/y',
#   'url': 'https://finnhub.io/api/news?id=8167eff64d15ae32bebca821ffa71f27ddf035d4e66c0d88979b97c12adbfc1a'},
#  {'category': 'company',
#   'datetime': 1748614698,
#   'headline': "Trump's tariffs and threatened trade actions",
#   'id': 134906472,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': "A federal appeals court on Thursday temporarily reinstated U.S.President Donald Trump's most sweeping tariffs, just a day after a trade court ruled that Trumphad overstepped his authority in...",
#   'url': 'https://finnhub.io/api/news?id=eb6a81269f5603288ce514208df68ace86e69736c8d299d3824cc1b3cef1ae11'},
#  {'category': 'company',
#   'datetime': 1748611776,
#   'headline': 'How The Fed And Uncertainty Can Push The S&P 500 Into A Correction',
#   'id': 134905934,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1402306256/image_1402306256.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'Is the S&P 500 overvalued? Discover why economic risks and high P/E ratios signal a potential 7%-10% correction, plus opportunities for gains in 2026!',
#   'url': 'https://finnhub.io/api/news?id=ce699c6f78f540dd5d3dc5165ee13812bdcaf6fca434f1f1aaebeaa3f1176720'},
#  {'category': 'company',
#   'datetime': 1748608772,
#   'headline': 'Latest News In Cloud AI - AI Market Transformation Drives Growth and Innovation',
#   'id': 134896710,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'The global Artificial Intelligence (AI) market is set for a significant transformation, with its value projected to soar from USD 371.71 billion in 2025 to USD 2,407.02 billion by 2032. Key drivers of this growth include the increased adoption of autonomous AI technologies, advancements in deep learning and machine learning, and enhanced computing power. Concurrently, the development of edge AI capabilities is promoting real-time data processing and decision-making, vital for sectors such as...',
#   'url': 'https://finnhub.io/api/news?id=0f32ce7557ce7c6ed56e737401b379b311affd28e02276a0208b52137816ec05'},
#  {'category': 'company',
#   'datetime': 1748604613,
#   'headline': 'Mag 7 valuations before & after Nvidia earnings: Chart of the Day',
#   'id': 134896714,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Now that Nvidia\'s (NVDA) earnings are in the books, Yahoo Finance host Julie Hyman takes a look at what Big Tech\'s valuations and forward price-to-earnings (P/E) ratios look like right now, particularly for the "Magnificent Seven." To watch more expert insights and analysis on the latest market action, check out more Asking for a Trend here.',
#   'url': 'https://finnhub.io/api/news?id=55a97fcc92abbdff92fb8db236afd2b9892fb4a8c492308218984379604b73c6'},
#  {'category': 'company',
#   'datetime': 1748602223,
#   'headline': 'FEPI Vs. QDTE: Both Funds Offer A Unique Value Proposition',
#   'id': 134903302,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=a53e9b0689da4a27714ddad72dc8f14bdff81ff0334429f74adb995aa432b559'},
#  {'category': 'company',
#   'datetime': 1748600026,
#   'headline': 'Foreign-branded mobile phone sales in China edge up in April',
#   'id': 134898472,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "BEIJING (Reuters) -Sales of foreign-branded mobile phones in China, including Apple Inc's iPhones, edged up in April, according to data released by a government-affiliated research company on Friday.  Calculations based on the data from the China Academy of Information and Communications Technology (CAICT) showed that April shipments of foreign-branded phones in China rose to 3.52 million units from 3.50 million a year earlier.  As the largest foreign mobile phone maker in China's smartphone-dominated market, Apple's performance plays a significant role in the overall data on foreign-branded phone sales in the country.",
#   'url': 'https://finnhub.io/api/news?id=74e3059cfd82ca8142a9855e31a3bfe0dad255f7ae2cf937bccbbd235629fa9d'},
#  {'category': 'company',
#   'datetime': 1748596553,
#   'headline': 'Smartphone Sales Growth Hit by Tariff ‘Whirlwind of Uncertainty’',
#   'id': 134898474,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- Sales of Apple Inc.’s iPhone and its closest rivals are expected to take a significant blow from the Trump administration’s new tariff policy unveiled in April.Most Read from BloombergNYC Congestion Toll Brings In $216 Million in First Four MonthsNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaThe Economic Benefits of Paying Workers to MoveNY Wins Order Against US Funding Freeze in Congestion FightWhy Arid Cities Should Stick TogetherTwo independent market',
#   'url': 'https://finnhub.io/api/news?id=2c2cd77c4357fbd0eda400c4ffc809241bc3ebe040e1a01be184b7cf2ec096e7'},
#  {'category': 'company',
#   'datetime': 1748595600,
#   'headline': "Elon Musk Thinks Tesla Will Be the World's Most Valuable Company, but This Huge Problem Could Send Its Stock Plunging by 70% Instead",
#   'id': 134896723,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Self-driving cars and humanoid robots are key to Musk's bullish vision for Tesla, but the company has to overcome major challenges first.  Tesla (NASDAQ: TSLA) stock hit a new record high in Dec. 2024 on the back of President Trump's election win.  Investors speculated that Trump's focus on deregulation could speed up the company's ability to commercialize its autonomous robotaxi and humanoid robot opportunities.",
#   'url': 'https://finnhub.io/api/news?id=7ef96eac3940784a9d3476fc0a2893bd3513e812cbc360fc0b5ac4ae0d0e4ca6'},
#  {'category': 'company',
#   'datetime': 1748592960,
#   'headline': 'Here’s what’s worth streaming in June 2025 as ‘The Bear’ and ‘Squid Game’ return',
#   'id': 134894777,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'Here’s what’s worth streaming in June 2025 as ‘The Bear’ and ‘Squid Game’ return',
#   'url': 'https://finnhub.io/api/news?id=fdf4a8ec24d63f09445d9f1b8e1b38794904dd002ceddea1baf335a51ec40b85'},
#  {'category': 'company',
#   'datetime': 1748592000,
#   'headline': 'Apple: Double-Down When The Market Gets Silly',
#   'id': 134894076,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1705316992/image_1705316992.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'Apple is down 20%, but historical trends suggest a rebound. Appleâ\x80\x99s history as a capable supply chain manager provides resilience. See more on AAPL stock here.',
#   'url': 'https://finnhub.io/api/news?id=41811e2fd73c54d46e61dbfdaa670fe34ea4ee7a1b7efd4f466e10073719487d'},
#  {'category': 'company',
#   'datetime': 1748586700,
#   'headline': 'Apple Plans OS Rebrand, Its Biggest Ever',
#   'id': 134893454,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': "Apple is planning to rename its operating systems based on the release year rather than version numbers. Bloomberg's Dana Wollman explains the reasoning behind the move in a conversation with...",
#   'url': 'https://finnhub.io/api/news?id=160583479cf2f8bd571fc64c4531c12bf9c191c8a10ba90b7de6afcbe7a3ed9a'},
#  {'category': 'company',
#   'datetime': 1748586254,
#   'headline': 'Stocks head for best month since 2023 ahead of inflation data',
#   'id': 134893408,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': 'World stocks were heading fortheir best month since late 2023 on Friday and the dollar wasflirting with its first monthly rise of the year, while traderswaited for key inflation data and assessed...',
#   'url': 'https://finnhub.io/api/news?id=97bf065afc2a239ab8ca30314f10cb605038f87024d0d3a607e0e30ea9b25f55'},
#  {'category': 'company',
#   'datetime': 1748583003,
#   'headline': 'Apple (AAPL) Rated Hold by Loop Capital Amid Tariff and iPhone 17 Buzz',
#   'id': 134898477,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'We recently published a list of 10 AI Stocks on Wall Street’s Radar. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other AI stocks on Wall Street’s radar. On May 28, Loop Capital analyst Ananda Baruah reiterated a “Hold” rating on Apple Inc. (NASDAQ:AAPL) and $215.00 […]',
#   'url': 'https://finnhub.io/api/news?id=6e342a4c13f26711a6abfee2a21eac3aebaf11ff5e458f0f9450bd3a30603fe8'},
#  {'category': 'company',
#   'datetime': 1748582652,
#   'headline': "China's April shipments of foreign-branded mobile phones up 0.8% from prior year",
#   'id': 134893031,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': "China's shipments offoreign-branded mobile phones, including Apple Inc'siPhones, were up 0.8% year-on-year in April, according to datareleased by a government-affiliated research company on...",
#   'url': 'https://finnhub.io/api/news?id=680d4d797eeaf096927694f379dbb00cca4695abf3e65e8901ac30178a69cec2'},
#  {'category': 'company',
#   'datetime': 1748577785,
#   'headline': 'Texas passes law requiring age verification in App Stores',
#   'id': 134892605,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': 'Copyright © BusinessAMBE 2023Key takeawaysTexas Governor Greg Abbott has signed a law requiring app stores to verify the age of users in the state.The law requires minors to get parental...',
#   'url': 'https://finnhub.io/api/news?id=2cbf448c97f78ba4a3acd9991ec84c718b3fd7edf874d67d39ee496eecf0bcae'},
#  {'category': 'company',
#   'datetime': 1748576700,
#   'headline': 'Generation PMCA Q1 2025 Quarterly',
#   'id': 134892455,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=28b28406674f5856cf17cb4c7a35e9390050aa3d0116aff9aafed85fc3e824d1'},
#  {'category': 'company',
#   'datetime': 1748567975,
#   'headline': "How Trump's trade war is upending the global economy",
#   'id': 134881848,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': "U.S. President Donald Trump's tariffdecisions since he took office on January 20 have shockedfinancial markets and sent a wave of uncertainty through theglobal economy. Here is a...",
#   'url': 'https://finnhub.io/api/news?id=b2c170f44e8ff27b21f295901719b3f4675c9d764c82ae5208c52db7f2b47be0'},
#  {'category': 'company',
#   'datetime': 1748565934,
#   'headline': 'Taiwan Says US Trade-Deal Push Still On Despite Court Ruling',
#   'id': 134866599,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- Taiwan is continuing efforts to secure a trade deal with the US, a top official in Taipei said, even after a court blocked many of the tariffs that President Donald Trump has threatened to impose on other countries.Most Read from BloombergNYC Congestion Toll Brings In $216 Million in First Four MonthsNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaThe Economic Benefits of Paying Workers to MoveNY Wins Order Against US Funding Freeze in Congestion FightNY Co',
#   'url': 'https://finnhub.io/api/news?id=a5f1c0eb82c5b469d00f2fc54ba6586fd1b6d02b77b60fbec9e1f03351c34030'},
#  {'category': 'company',
#   'datetime': 1748552030,
#   'headline': "Tracking Ray Dalio's Bridgewater Associates 13F Portfolio - Q1 2025 Update",
#   'id': 134863792,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1333504671/image_1333504671.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': "See an update on Bridgewater Associates' Q1'25 portfolio shifts, highlighting top stock changes in tech and retail, diversification strategies, & key holdings.",
#   'url': 'https://finnhub.io/api/news?id=065e3ec67a0a852f8de27f888c48bbc88870b963b8035abf2eaab07f900ec8b7'},
#  {'category': 'company',
#   'datetime': 1748551431,
#   'headline': 'Appeals Court Rescues Trump Tariffs On China, Apple And The World; S&P 500 Rises',
#   'id': 134871307,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "A federal appeals court on Thursday granted the Trump administration's request for a stay of a Wednesday ruling that President Donald Trump overstepped his authority in imposing reciprocal tariffs announced on April 2 and earlier tariffs aimed at China, Mexico and Canada.  The S&P 500 barely reacted to the latest Trump tariffs twist, remaining slightly higher on the session.  The stay granted by the U.S. Court of Appeals for the Federal Circuit is a short-term one — while the court considers filings from both plaintiffs and the U.S. that are due by June 9.",
#   'url': 'https://finnhub.io/api/news?id=1030127512d946bef6b56b9cbb15aeac9532952400ba0a20cf053ff67e5c82a2'},
#  {'category': 'company',
#   'datetime': 1748550154,
#   'headline': 'Jim Cramer on Apple Inc. (AAPL): “They’ll Have the Best AI”',
#   'id': 134871308,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'We recently published a list of Jim Cramer Put These 14 Stocks Under the Microscope. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other stocks that Jim Cramer discusses. While discussing Apple Inc. (NASDAQ:AAPL), Cramer praised the company’s CEO as he said: “… The endless carping […]',
#   'url': 'https://finnhub.io/api/news?id=40c1f263e0a0073b3fdd36ff267b2373a4c8e3aa96a13e88e46a3a9efa732872'},
#  {'category': 'company',
#   'datetime': 1748547569,
#   'headline': "Apple's App Store Billings Triple to $406 Billion in Five Years",
#   'id': 134871310,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple reports 76% spike in small-developer earnings and 90% no-commission volume',
#   'url': 'https://finnhub.io/api/news?id=988cfa95af3780706e2e60b2e8b8692a09d7439562f312befee72fdc8c50f01b'},
#  {'category': 'company',
#   'datetime': 1748547263,
#   'headline': 'Apple Dips as IDC Cuts Smartphone Forecast',
#   'id': 134871311,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'IDC sees just 0.6% shipment growth in 2025 amid tariff, subsidy and competition headwinds',
#   'url': 'https://finnhub.io/api/news?id=7db35531baf235765eb332be7f1e758f43e0c3090e0654186be34c4859d546d8'},
#  {'category': 'company',
#   'datetime': 1748546688,
#   'headline': 'iPhone Shipments Still Set to Grow Despite Tariffs, Research Firm Says',
#   'id': 134871312,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'U.S. iPhone shipments are expected to grow 2.5% this year, IDC estimates, a figure that’s lower than the 3.4% the research firm previously expected but is nonetheless robust in the face of tariff headwinds.  Surprisingly, its forecast for global iPhone shipments is basically flat at 1.7% growth compared with its prior forecast of 1.8% growth.  IDC also reduced its 2025 growth projections for overall global smartphone shipments to 0.6%, down from a 2.3% forecast made in February before President Trump’s Liberation Day tariff announcement.',
#   'url': 'https://finnhub.io/api/news?id=d339f77afc7aaeeee512d09d0d0a688c8bcde7165fc4f05f720da9df92fb77bd'},
#  {'category': 'company',
#   'datetime': 1748546122,
#   'headline': 'UBS Reiterates Neutral on Apple (AAPL) as Tariff Talk Sparks iPhone Buying Surge',
#   'id': 134871313,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'We recently published a list of 12 AI Stocks on Latest News and Ratings. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other AI stocks on latest news and ratings. One of the most notable analyst calls on Tuesday, May 28, was for Apple Inc. (NASDAQ:AAPL). […]',
#   'url': 'https://finnhub.io/api/news?id=33c661f7b89e58a371d9341b1890072c4a65666d1204b22fa3970ebe879eeade'},
#  {'category': 'company',
#   'datetime': 1748542885,
#   'headline': 'Evercore Unfazed: $205 Target Reaffirmed Despite GOOG Underperformance',
#   'id': 134860066,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Evercore ISI recently reiterated an Outperform rating and $205 price target on Alphabet Inc. (NASDAQ:GOOG) shares. Alphabet is a technology company that owns and runs the internet search engine Google. In an investor note, the analyst noted that Alphabet shares had traded down following reports that Apple Senior VP of Services Eddy Cue testified that […]',
#   'url': 'https://finnhub.io/api/news?id=e657c045d8576a66ee136217913afe4e55e140a9bb800a719cf3616952ddfb55'},
#  {'category': 'company',
#   'datetime': 1748542617,
#   'headline': 'Wedbush: Apple Inc. (NASDAQ:AAPL) Could Face US Pressure, But India Key to Avoiding $3,500 iPhones',
#   'id': 134871315,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Wedbush analyst Daniel Ives believes Outperform-rated Apple Inc. (NASDAQ:AAPL) has put itself in a very hedged supply chain strategy heading into iPhone 17 production this Fall. Apple is a consumer electronics firm. All of the advisory’s work in the supply chain throughout Asia over the past few weeks gives it a high level of confidence […]',
#   'url': 'https://finnhub.io/api/news?id=bafc29174e6dd725186a76e7ec1500acdcac52516e3363b3207053f89b86e4da'},
#  {'category': 'company',
#   'datetime': 1748539818,
#   'headline': 'Google To Launch Direct Sales and Physical Stores in India',
#   'id': 134860070,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Alphabet Inc.’s (NASDAQ:GOOGL) Google has joined Apple in enabling direct hardware sales in India. On May 28, the company began direct sale of Pixel Phones, watches, and earbuds in India ahead of an official launch in physical stores. Over the years, the company has sold its products through authorized retailers and e-commerce platform Flipkart. Media […]',
#   'url': 'https://finnhub.io/api/news?id=858df80789d2c5a893d458a5196d45ce57b42bf2028951eb86571277a46a2850'},
#  {'category': 'company',
#   'datetime': 1748539772,
#   'headline': 'ETB: Hard To Recommend This Fund In A Bull Market',
#   'id': 134851689,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/2153687482/image_2153687482.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': "Read about ETB's 9.2% yield, its performance limits in bull markets, and why ETY might be a better choice for long-term growth.",
#   'url': 'https://finnhub.io/api/news?id=121a4a7ceefcf5b447ce8776868b781fc1849549fc91025f965b9f5d2f05ac0c'},
#  {'category': 'company',
#   'datetime': 1748539309,
#   'headline': 'UBS Maintains Neutral Rating on Apple (AAPL), Keeps $210 PT',
#   'id': 134871318,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'On Tuesday, May 27, UBS analysts reiterated a “Neutral” rating with a steady $210 price target for Apple Inc. (NASDAQ:AAPL). This decision came after President Trump posted on social media and threatened to impose a 25% tariff on iPhones that are not manufactured in the US. Despite this threat, UBS analysts expect the impact of […]',
#   'url': 'https://finnhub.io/api/news?id=e221fd5cddfb7b48849783774373dd2aacb4e5a1235aec2b3fa04a07ad2253cc'},
#  {'category': 'company',
#   'datetime': 1748537220,
#   'headline': 'Nvidia’s Most Impressive Feat Yet? How the Chip Maker Overcame a China Ban.',
#   'id': 134894692,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'Nvidia’s Most Impressive Feat Yet? How the Chip Maker Overcame a China Ban.',
#   'url': 'https://finnhub.io/api/news?id=98d513464937b903791eae8079abdf9533d9c91eeb6a4087c8b07958ec7055ca'},
#  {'category': 'company',
#   'datetime': 1748537100,
#   'headline': 'Berkshire Hathaway Stock Is Slipping. The ‘Buffett Premium’ Is Leaking Out.',
#   'id': 134894779,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'Berkshire Hathaway Stock Is Slipping. The ‘Buffett Premium’ Is Leaking Out.',
#   'url': 'https://finnhub.io/api/news?id=ef21a730f326fb8407ba178a97a15b3614c573abe6ea3412615001e69bff418c'},
#  {'category': 'company',
#   'datetime': 1748536327,
#   'headline': "'Why Pay $1,800 Instead Of $300?' Kevin O'Leary Breaks Down The Real Reason Apple Fans Keep Buying — And How You Can Copy It",
#   'id': 134871319,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '"Why pay $1,800 instead of $300?" "Shark Tank" investor Kevin O\'Leary says it feels rational when a logo gives buyers a sense of belonging. In a May 9 Instagram Reel, O\'Leary compared Apple\'s (NASDAQ:AAPL) MacBook with bargain Microsoft (NASDAQ:MSFT) Windows laptops, arguing that brands are built around communities. His premise: hardware parity fades once a company wraps its products in identity, service, and storytelling—and that moat is worth every premium dollar for both investors and everyda',
#   'url': 'https://finnhub.io/api/news?id=31d5e84ac27cb1b4ebffe1a21def362834f0e1d14f4b216bba3b171349df1958'},
#  {'category': 'company',
#   'datetime': 1748536140,
#   'headline': 'Marvell Earnings Are Solid but Not Enough for Wall Street',
#   'id': 134894745,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'Marvell Earnings Are Solid but Not Enough for Wall Street',
#   'url': 'https://finnhub.io/api/news?id=a0e00f6a0514ff0a215fc04cd495b29b3d108b82824302a638dc8dcd830ea1f3'},
#  {'category': 'company',
#   'datetime': 1748534355,
#   'headline': 'Big Tech stocks pare gains as uncertainty looms over Trump tariffs',
#   'id': 134860074,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Big Tech stocks pared gains after a brief spike Thursday morning following a US trade court decision that invalidates the vast majority of Trump’s global tariffs.',
#   'url': 'https://finnhub.io/api/news?id=87af30d0ec2d131bd9658b5a77d4b8b8d9fff9a70b754eaada4261c99b9f3b51'},
#  {'category': 'company',
#   'datetime': 1748534220,
#   'headline': 'Madison Covered Call & Equity Income Fund Q1 2025 Investment Strategy Letter',
#   'id': 134846404,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/160616076/image_160616076.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'Over the full quarter, the S&P 500 lost 4.3% while the CBOE S&P 500 Buy-Write Index fell 3.1%. The Fund (class Y) outperformed both benchmarks, posting a 1.9% decline.',
#   'url': 'https://finnhub.io/api/news?id=43556fe92240db93ab787bdcbe7e2b77cce16437a7b5e0a509579ccef446c731'},
#  {'category': 'company',
#   'datetime': 1748533785,
#   'headline': "Nvidia Briefly Reclaims Title of World's Most Valuable Company on Solid Earnings",
#   'id': 134871323,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Nvidia briefly returned to the top of the list of the world's most valuable companies when its stock soared in early trading Thursday following a strong first-quarter earnings report.",
#   'url': 'https://finnhub.io/api/news?id=56b8ccf90160992dc82d25c1c19d43c12fd08ef4570a0ccc79b90056e3615999'},
#  {'category': 'company',
#   'datetime': 1748526009,
#   'headline': 'Microsoft Shares Go From Laggard to Leader as AI Growth Improves',
#   'id': 134808903,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- After languishing for months, Microsoft Corp. shares are back within striking distance of a record high amid signs that performance in its Azure cloud-computing business is back on track. Most Read from BloombergNYC Congestion Toll Brings In $216 Million in First Four MonthsNY Wins Order Against US Funding Freeze in Congestion FightNow With Colorful Blocks, Tirana’s Pyramid Represents a Changing AlbaniaNY Congestion Pricing Is Likely to Stay Until Year End During Court CaseThe sof',
#   'url': 'https://finnhub.io/api/news?id=55c963ae97ba5c189d6faf9d132e63fbc07e789a7a858dd57b97b78309bdaada'},
#  {'category': 'company',
#   'datetime': 1748523051,
#   'headline': 'Court Slashes Trump Tariffs On China, Apple And The World — For Now; S&P 500 Futures Climb',
#   'id': 134811429,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "A federal court struck down President Trump's tariffs on China, Apple and most of the world, but it may be temporary. S&P 500 futures rose.",
#   'url': 'https://finnhub.io/api/news?id=1018e5dbd5a4818e916dd9ca48016fe5541a55ae9e4150e7485b7550625476f4'},
#  {'category': 'company',
#   'datetime': 1748521800,
#   'headline': '2 Underrated Artificial Intelligence (AI) Stocks to Buy and Hold',
#   'id': 134811435,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Generative AI can simplify and speed up many tasks, including content production.  It's easy to see the potential for Netflix, whose content strategy is integral to its success.  Netflix's creations have attracted millions of viewers and won many awards.",
#   'url': 'https://finnhub.io/api/news?id=b560b429e8557fe9654be6ab0032c2f42cc9daee1a13d664864261c12d596eab'},
#  {'category': 'company',
#   'datetime': 1748520920,
#   'headline': "Trump's tariff tally: $34 billion and counting, global companies say",
#   'id': 134821599,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': '* Companies face uncertainty, paralyzing decision-making andaffecting profit forecasts * Economists predict final costs will be much higher thandisclosed ...',
#   'url': 'https://finnhub.io/api/news?id=6fc8da1c3b3737212f0398e8144dda149cd22e201ca2706849831a1e1e54ce14'},
#  {'category': 'company',
#   'datetime': 1748520859,
#   'headline': 'Apple is falling behind its Magnificent 7 rivals. Should it just be the Mag 6?',
#   'id': 134811309,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'The “Magnificent Seven” tech stocks led the market’s post-pandemic boom. But as Big Tech sprints into the AI future, one big name is falling dangerously behind: Apple (AAPL). Once an undisputed tech heavyweight, it risks becoming the least magnificent of them all.',
#   'url': 'https://finnhub.io/api/news?id=aa893f254949d2bf8a85bdc76e57377ed2109e27c47219ed7a509ac41bb14c84'},
#  {'category': 'company',
#   'datetime': 1748519342,
#   'headline': "3 Reasons I'm Buying Nvidia After Earnings And So Should You",
#   'id': 134819719,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1277377483/image_1277377483.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': "Discover why Nvidia Corporation's 44% EPS growth, AI dominance, and undervaluation signal a rare hypergrowth investment. Click for my NVDA Q1 earnings update.",
#   'url': 'https://finnhub.io/api/news?id=498c90884b3c637e4576ee3cebb1cfdfb9c350dd05b870837cbd70744115ea70'},
#  {'category': 'company',
#   'datetime': 1748518200,
#   'headline': 'You Mess With The Don, You (Might) Get The Tariffs',
#   'id': 134817144,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/2217166890/image_2217166890.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': "Explore how tariff rulings impact the 'TACO Trade' strategy. Learn how volatility creates opportunities & what the Supreme Court decision means for markets.",
#   'url': 'https://finnhub.io/api/news?id=9ace3e38c048e38b93b1d6256e44e16053c1394e3e2a1b86f3ec57318ad668ad'},
#  {'category': 'company',
#   'datetime': 1748515139,
#   'headline': 'Big Tech ETF climbs as Nvidia’s rally tops all other stocks in the Dow',
#   'id': 134811356,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'Big Tech ETF climbs as Nvidia’s rally tops all other stocks in the Dow',
#   'url': 'https://finnhub.io/api/news?id=38207a284aa6f0a50ccd3d517875911580d515818655d68db11bf717bf7e1b2f'},
#  {'category': 'company',
#   'datetime': 1748512560,
#   'headline': 'These Stocks Are Moving the Most Today: Nvidia, Apple, HP Inc., Tesla, C3.ai, e.l.f. Beauty, SentinelOne, and More',
#   'id': 134811522,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'These Stocks Are Moving the Most Today: Nvidia, Apple, HP Inc., Tesla, C3.ai, e.l.f. Beauty, SentinelOne, and More',
#   'url': 'https://finnhub.io/api/news?id=3e69984e91183302b4fe63587a578bd100b2f593e50b8652ece25cf45a079b8b'},
#  {'category': 'company',
#   'datetime': 1748510580,
#   'headline': 'Why Wall Street downgrades of Apple stock are about to pile up',
#   'id': 134811645,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'Why Wall Street downgrades of Apple stock are about to pile up',
#   'url': 'https://finnhub.io/api/news?id=af31c2c89deb3dd9e4fce57603179dc99739e6d33d25d99a74a10a11b703aca5'},
#  {'category': 'company',
#   'datetime': 1748510100,
#   'headline': "Apple's Perfect Storm: Tariffs, China, AI, And Innovation",
#   'id': 134806699,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/516837044/image_516837044.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
# ...
#   'url': 'https://finnhub.io/api/news?id=c93d4bed3ef473a8692ab37f73dc1d59f9d6e8f1d6a75fc55a6173b51d55399a'},
#  {'category': 'company',
#   'datetime': 1748073600,
#   'headline': '5 Best CEFs This Month For Yields Up To 14% (May 2025)',
#   'id': 134687749,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=b75c7d61e883a81f425a93fd499175b0ca3c9bb887e49e5974fcd7bdfea8be17'},
#  {'category': 'company',
#   'datetime': 1748072004,
#   'headline': 'What Moved Markets This Week',
#   'id': 134687638,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=acb3ec55ca75ecffcb330931394cd12c59292ada6cc21075f0ef9d9081ba98c6'},
#  {'category': 'company',
#   'datetime': 1748059200,
#   'headline': 'AP Top Financial News at 8:07 a.m. EDT',
#   'id': 134694220,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple has had few incentives in the past to start making iPhones in US',
#   'url': 'https://finnhub.io/api/news?id=2ccdb33808556bb3990b26997777e01395ece91a04b0b9e0d10e7a3f6e1a8510'},
#  {'category': 'company',
#   'datetime': 1748057486,
#   'headline': "Apple Faces 'First Serious Threat In 20 Years' As OpenAI Acquires iPhone Maker's Former Design Chief Jony Ive's Hardware Startup, Says Gene Munster",
#   'id': 134685582,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Gene Munster, Managing Partner at Deepwater Asset Management, warned Wednesday that OpenAI represents the first serious competitive threat to Apple Inc. (NASDAQ:AAPL) in two decades following the artificial intelligence company’s $6.5 billion acquisition of former Apple design chief Jony Ive‘s hardware startup. What Happened: “The real risk for AAPL is whether the threat of these devices from OpenAI compresses Apple’s multiple,” Munster wrote on X, highlighting concerns about the iPhone maker’s',
#   'url': 'https://finnhub.io/api/news?id=625babdf9899ed45b49539aff7b80c993ea3fede431a3bb7faaed89c89893e54'},
#  {'category': 'company',
#   'datetime': 1748052000,
#   'headline': 'Tim Cook’s Bad Year Keeps Getting Worse',
#   'id': 134685583,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'On Friday, President Trump targeted  Apple  with new demands that the company make iPhones in the U.S., threatening 25% tariffs if the company doesn’t comply.  “Rise and shine Tim Cook,” Trump whisperer  Laura Loomer  posted on X, reminding the Apple CEO he is at the center of the president’s trade bull’s-eye.  Aside from Trump, Cook is facing off against two U.S. judges, European and worldwide regulators, state and federal lawmakers, and even a creator of the iPhone, to say nothing of the cast of rivals outrunning Apple in artificial intelligence.',
#   'url': 'https://finnhub.io/api/news?id=dad4b3c49813a194b67b88363216f5d048d613ec6d85da1d60b8257f1cfb2fe1'},
#  {'category': 'company',
#   'datetime': 1748042100,
#   'headline': 'Columbia Balanced Fund Q1 2025 Commentary',
#   'id': 134684612,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=0385c794f7ed58aa50e2427ed31d1d76b351c3bcb93035845a5783a9f42968ef'},
#  {'category': 'company',
#   'datetime': 1748037450,
#   'headline': 'Stocks to Watch: Apple, Booz Allen,  Constellation Energy, Intuit',
#   'id': 134685584,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '↘️ Booz Allen (BAH): The company plans to cut roughly 2,500 jobs as it grapples with the effects of the Trump administration’s crackdown on federal contracting. Shares dropped more than 16%. ↘️ Apple (AAPL): President Trump racketed up pressure on Apple, saying iPhones manufactured abroad could face import taxes of at least 25%.',
#   'url': 'https://finnhub.io/api/news?id=bfd54d01a226bc1e24b03f6bed55de4ce2e7aa6cdfdc5ec84c1ad09264c1eb50'},
#  {'category': 'company',
#   'datetime': 1748036400,
#   'headline': 'Tim Cook Called Texas Governor to Stop Online Child-Safety Legislation',
#   'id': 134685585,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple’s CEO called Texas Gov. Greg Abbott after a law passed requiring app stores to verify user ages.',
#   'url': 'https://finnhub.io/api/news?id=bbb45d89dffa0c9c424208fbd699effb88e2d2cba22699e7ab2f8d5bdb0eada3'},
#  {'category': 'company',
#   'datetime': 1748034900,
#   'headline': 'Trump Threatens Fresh Tariffs on EU, iPhones and Rival Devices',
#   'id': 134685586,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'President Trump fired new salvos in the global trade war, threatening a 50% tariff on imported goods from the European Union and new duties on iPhones and other smartphones made overseas.',
#   'url': 'https://finnhub.io/api/news?id=2a8e5878890dbd7cb4550a414000400c131163b7bc7b6b6d3817ca22ecab676e'},
#  {'category': 'company',
#   'datetime': 1748034300,
#   'headline': 'Stocks Take Another Tariff To The Shin',
#   'id': 134684173,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/2197351521/image_2197351521.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'Markets sagged again Friday after a fresh round of tariff threats landed like a sandbag, flattening retailers still wheezing from the last batch.',
#   'url': 'https://finnhub.io/api/news?id=89ee8af1f6918ecf1ca8d31ee6ae7c62abe612f05f802f065c7f46e866201beb'},
#  {'category': 'company',
#   'datetime': 1748033993,
#   'headline': "Wall Street Declines After Trump's Fresh Tariff Threats; Apple Falls 3%",
#   'id': 134685587,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "US benchmark equity indexes declined on Friday as President Donald Trump's tariff threats against th",
#   'url': 'https://finnhub.io/api/news?id=bd07211360dd6c0d542c9779f3f9ae624dab1c4646ee29ec93c1d7ce328f4fc9'},
#  {'category': 'company',
#   'datetime': 1748033963,
#   'headline': 'Trump Threatens EU, Smartphones as Tariff Rhetoric Escalates',
#   'id': 134685588,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- Supply Lines is a daily newsletter that tracks global trade. Sign up here.Most Read from BloombergNY Private School Pleads for Donors to Stay Open After Declaring BankruptcyUAE’s AI University Aims to Become Stanford of the GulfCan Frank Gehry’s ‘Grand LA’ Make Downtown Feel Like a Neighborhood?NYC’s War on Trash Gets a Glam SquadChicago’s O’Hare Airport Seeks Up to $4.3 Billion of Muni DebtPresident Donald Trump dug in on his threat to impose a 50% tariff on the European Union an',
#   'url': 'https://finnhub.io/api/news?id=eac7308328e8802d9a51a2a235a161a62369f0c9837d07ae714668ed8fac299c'},
#  {'category': 'company',
#   'datetime': 1748033762,
#   'headline': 'Trump Targets Samsung, Apple Phones With 25% Tariff Threat',
#   'id': 134685589,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- Supply Lines is a daily newsletter that tracks global trade. Sign up here.Most Read from BloombergNY Private School Pleads for Donors to Stay Open After Declaring BankruptcyUAE’s AI University Aims to Become Stanford of the GulfCan Frank Gehry’s ‘Grand LA’ Make Downtown Feel Like a Neighborhood?NYC’s War on Trash Gets a Glam SquadChicago’s O’Hare Airport Seeks Up to $4.3 Billion of Muni DebtPresident Donald Trump said that the tariffs he threatened against Apple Inc. earlier Frida',
#   'url': 'https://finnhub.io/api/news?id=6aed5b6d257584663820fdff8a3d0f81ecb4bec99b6a00b56a78d024e74f1cac'},
#  {'category': 'company',
#   'datetime': 1748033450,
#   'headline': 'US Equity Indexes Fall in Week on Treasury Market Jitters, Trump Warnings to EU, Apple',
#   'id': 134685590,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "US equity indexes fell this week as the White House's budget bill triggered jitters in the Treasury",
#   'url': 'https://finnhub.io/api/news?id=e838ab7419c7d17b7131325a3cdc3cfd9cd5cae0076cedc35dc0f646e83a759c'},
#  {'category': 'company',
#   'datetime': 1748032860,
#   'headline': 'Stocks Fall on Tariff Broadside, After Week of Bond Market Agita',
#   'id': 134685591,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'President Trump renewed his tariff campaign Friday, threatening to impose a 50% rate on the European Union and warning  Apple  that foreign-made iPhones could face significant levies.  Shares of Apple lost 3%, while broader stock indexes finished the day lower by 0.6% to 1%.  The S&P 500 index ended the week down 2.6%; the Dow Jones Industrial Average and the Nasdaq Composite both fell 2.5%.',
#   'url': 'https://finnhub.io/api/news?id=acd4ddbf89a7fa88e286274c3fac84d8f7f007392654c263edd8652aa53c9373'},
#  {'category': 'company',
#   'datetime': 1748031570,
#   'headline': 'Apple Stock Falls As Trump Threatens iPhone Tariff',
#   'id': 134685592,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple stock fell Friday after President Donald Trump threatened to put a tariff on Apple iPhones of “at least 25%.”',
#   'url': 'https://finnhub.io/api/news?id=74ee9805dacb5a1410d793da62df00a30e003457afe089f4880ae9f29b59f4ba'},
#  {'category': 'company',
#   'datetime': 1748031480,
#   'headline': 'Apple Is Unlikely to Escape Tariffs This Time. Trump Is Doubling Down.',
#   'id': 134685593,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Apple stock was dropping on Friday after President Donald Trump threatened a 25% tariff on its iPhones sold in the U.S. unless they are made in the U.S.',
#   'url': 'https://finnhub.io/api/news?id=b5637b17166a2816de768f9383e807dc643faadda4ba2fa13add5e0836949ebb'},
#  {'category': 'company',
#   'datetime': 1748031379,
#   'headline': 'Dollar Falls to Lowest Since 2023 as Investors Eye Trade Risks',
#   'id': 134685594,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- The US dollar slumped to its lowest level since 2023 as new tariff threats from President Donald Trump and the risk of a widening fiscal deficit drag on the currency’s appeal.Most Read from BloombergNY Private School Pleads for Donors to Stay Open After Declaring BankruptcyUAE’s AI University Aims to Become Stanford of the GulfCan Frank Gehry’s ‘Grand LA’ Make Downtown Feel Like a Neighborhood?NYC’s War on Trash Gets a Glam SquadChicago’s O’Hare Airport Seeks Up to $4.3 Billion of',
#   'url': 'https://finnhub.io/api/news?id=a910d3b05a7bcd03e36bdd3745d3537aea4d59a69834f694441250914db143b6'},
#  {'category': 'company',
#   'datetime': 1748031264,
#   'headline': 'Equity Markets Close Lower as Trump Proposes New Tariffs on EU, Apple',
#   'id': 134685595,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'US benchmark equity indexes closed lower on Friday, as President Donald Trump threatens new tariffs',
#   'url': 'https://finnhub.io/api/news?id=a16e1dbb6453be87ea92478351c9006b8daa502eebcf0d7874d2713c46287d59'},
#  {'category': 'company',
#   'datetime': 1748030961,
#   'headline': 'Markets dip after Trump threatens tariffs against Europe and Apple, sinking the iPhone maker’s stock by 3%',
#   'id': 134685596,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'The president said he would issue a 50% tariff on the EU and a 25% tax on Apple in a pair of Truth Social posts.',
#   'url': 'https://finnhub.io/api/news?id=7aecca6f6a963dd2925b562f0d21835551e4f5df1fa92f69c0216cb23d5a90a3'},
#  {'category': 'company',
#   'datetime': 1748030880,
#   'headline': 'Tim Cook to Donald Trump: You Were Serious About That?',
#   'id': 134685597,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Just moving out of China won’t be enough for Apple to satisfy the president’s demands for U.S. production, Ben Rose writes in a guest commentary.',
#   'url': 'https://finnhub.io/api/news?id=3cc9a969650257c4024f8081abf1594d407e781865fcb348d51c018fb7a500b0'},
#  {'category': 'company',
#   'datetime': 1748030690,
#   'headline': "The problem with Trump's call for Apple to make iPhones in the US",
#   'id': 134685598,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'President Trump says Apple (AAPL), along with other smartphone makers like Samsung (005930.KS), will have to pay a 25% tariff for every iPhone sold in the US that wasn\'t made domestically. Epistrophy Capital Research chief market strategist and host of "The Drill Down" podcast, Cory Johnson, joins Market Domination to discuss the dynamics that prevent Apple from making iPhones in the US. To watch more expert insights and analysis on the latest market action, check out more Market Domination here.',
#   'url': 'https://finnhub.io/api/news?id=a0cf96ec65169e2b976ed6b1ef3ab5750709da27ad39d1045af28f43f4474692'},
#  {'category': 'company',
#   'datetime': 1748030491,
#   'headline': "US Equities Markets End Lower Friday After Trump's EU, Apple Tariff Threats",
#   'id': 134685599,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'US benchmark equity indexes ended lower Friday as President Donald Trump threatened new tariffs agai',
#   'url': 'https://finnhub.io/api/news?id=342e6352682c031a617938fc571bd0c7f072fbbb5ec04f73e071caae1b185e63'},
#  {'category': 'company',
#   'datetime': 1748030455,
#   'headline': 'Stock market today: Dow, S&P 500, Nasdaq fall as Trump tariff threats roar back, US deficit anxiety deepens',
#   'id': 134685600,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': "Wall Street is assessing President Trump''s tariff salvo on Apple and what his giant tax bill means for the deficit and the economy.",
#   'url': 'https://finnhub.io/api/news?id=1aca6ae325cbe7c149f057794dd522779bee24709ada35f2f6f65a038023adfd'},
#  {'category': 'company',
#   'datetime': 1748029737,
#   'headline': 'Sector Update: Tech Stocks Fall Late Afternoon',
#   'id': 134685601,
#   'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png',
#   'related': 'AAPL',
#   'source': 'Yahoo',
#   'summary': 'Tech stocks were in the red late Friday afternoon, with the Technology Select Sector SPDR Fund (XLK)',
#   'url': 'https://finnhub.io/api/news?id=2016f291000c11383d871640f42ba1da068fa549c99ac1ae86b656c64f81dc48'},
#  {'category': 'company',
#   'datetime': 1748028724,
#   'headline': 'WRAPUP 8-Trump threatens new tariffs on European Union and Apple, reigniting trade fears',
#   'id': 134683874,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'Finnhub',
#   'summary': "* Trump threatens 25% tariff on non-US-made iPhones * Proposed tariff on Apple would also apply to Samsung,Trump says * President says, 'I'm...",
#   'url': 'https://finnhub.io/api/news?id=d9cd3382aaa49c7859433f14e280cd8cb68539c6c0be3e6b1abc41edb761391b'}]

# %% [markdown]
# #### `get_basic_financials_history(...)`
#
# - `finnhub_client.company_basic_financials(symbol, "all")`: 获取指定公司的所有基本财务数据.
#
# - 使用 `defaultdict(dict)` 来组织数据。遍历从API获取的特定频率 (`freq`) 的财务指标 (`metric`) 和对应的值列表 (`value_list`)。
# - 返回dataframe

# %%
FinnHubUtils.get_basic_financials_history(
    symbol="AAPL",
    freq="quarterly",
    start_date="2022-06-01",
    end_date="2025-06-01",
    selected_columns=[
        "eps", "grossMargin", "netMargin", "roaTTM", "roeTTM", "peTTM"
    ],
    save_path="./AAPL_financials_quarterly.csv"
)
# Out:
# Finnhub client initialized
# basic financials saved to ./AAPL_financials_quarterly.csv
#                eps  grossMargin  netMargin    peTTM  roaTTM  roeTTM
# date
# 2025-03-29  1.6458       0.4705     0.2599  34.3327  0.2837  1.5131
# 2024-12-28  2.3979       0.4688     0.2923  39.6486  0.2791  1.4535
# 2024-09-28  0.9667       0.4622     0.1552  37.5759  0.2702  1.3787
# 2024-06-29  1.3974       0.4626     0.2500  32.3613  0.2966  1.4715
# 2024-03-30  1.5284       0.4658     0.2604  26.3771  0.2913  1.4833
# 2023-12-30  2.1774       0.4587     0.2836  29.6728  0.2939  1.5604
# 2023-09-30  1.4647       0.4517     0.2565  27.8553  0.2839  1.6078
# 2023-07-01  1.2603       0.4452     0.2431  31.7812  0.2773  1.6492
# 2023-04-01  1.5246       0.4426     0.2548  27.7007  0.2758  1.6572
# 2022-12-31  1.8801       0.4296     0.2561  21.7182  0.2746  1.6345
# 2022-09-24  1.2855       0.4226     0.2299  24.0854  0.2810  1.6090
# 2022-06-25  1.1955       0.4326     0.2344  22.8847  0.2808  1.5297

# %%
basic_financials = finnhub_client.company_basic_financials("AAPL", "all")

import json
print(json.dumps(basic_financials, indent=2))
# Out:
# {
#   "metric": {
#     "10DayAverageTradingVolume": 55.16882,
#     "13WeekPriceReturnDaily": -15.3603,
#     "26WeekPriceReturnDaily": -12.2926,
#     "3MonthADReturnStd": 51.084312,
#     "3MonthAverageTradingVolume": 59.25201,
#     "52WeekHigh": 260.1,
#     "52WeekHighDate": "2024-12-26",
#     "52WeekLow": 169.2101,
#     "52WeekLowDate": "2025-04-08",
#     "52WeekPriceReturnDaily": 5.5494,
#     "5DayPriceReturnDaily": 2.8576,
#     "assetTurnoverAnnual": 1.0714,
#     "assetTurnoverTTM": 1.1673,
#     "beta": 1.2146548,
#     "bookValuePerShareAnnual": 3.7673,
#     "bookValuePerShareQuarterly": 4.4712,
#     "bookValueShareGrowth5Y": -5.85,
#     "capexCagr5Y": -2.08,
#     "cashFlowPerShareAnnual": 7.1978,
#     "cashFlowPerShareQuarterly": 6.5924,
#     "cashFlowPerShareTTM": 6.86253,
#     "cashPerSharePerShareAnnual": 4.3112,
#     "cashPerSharePerShareQuarterly": 3.2463,
#     "currentDividendYieldTTM": 0.5105,
#     "currentEv/freeCashFlowAnnual": 28.214,
#     "currentEv/freeCashFlowTTM": 31.1708,
#     "currentRatioAnnual": 0.8673,
#     "currentRatioQuarterly": 0.8209,
#     "dividendGrowthRate5Y": 5.3,
#     "dividendPerShareAnnual": 0.9935,
#     "dividendPerShareTTM": 1.0115,
#     "dividendYieldIndicatedAnnual": 0.5177993,
#     "ebitdPerShareAnnual": 8.7571,
#     "ebitdPerShareTTM": 9.1121,
#     "ebitdaCagr5Y": 11.9,
#     "ebitdaInterimCagr5Y": 15.39,
#     "enterpriseValue": 3069884.8,
#     "epsAnnual": 6.0836,
#     "epsBasicExclExtraItemsAnnual": 6.0836,
#     "epsBasicExclExtraItemsTTM": 6.4078,
#     "epsExclExtraItemsAnnual": 6.0836,
#     "epsExclExtraItemsTTM": 6.4078,
#     "epsGrowth3Y": 2.71,
#     "epsGrowth5Y": 15.41,
#     "epsGrowthQuarterlyYoy": 7.68,
#     "epsGrowthTTMYoy": -0.36,
#     "epsInclExtraItemsAnnual": 6.0836,
#     "epsInclExtraItemsTTM": 6.4078,
#     "epsNormalizedAnnual": 6.0836,
#     "epsTTM": 6.4078,
#     "focfCagr5Y": 13.06,
#     "grossMargin5Y": 42.73,
#     "grossMarginAnnual": 46.21,
#     "grossMarginTTM": 46.63,
#     "inventoryTurnoverAnnual": 30.8955,
#     "inventoryTurnoverTTM": 34.184,
#     "longTermDebt/equityAnnual": 1.5057,
#     "longTermDebt/equityQuarterly": 1.1762,
#     "marketCapitalization": 2999860.8,
#     "monthToDatePriceReturnDaily": -5.4824,
#     "netIncomeEmployeeAnnual": 0.5716,
#     "netIncomeEmployeeTTM": 0.5933,
#     "netInterestCoverageAnnual": 622.5082,
#     "netInterestCoverageTTM": 622.5082,
#     "netMarginGrowth5Y": 2.45,
#     "netProfitMargin5Y": 24.28,
#     "netProfitMarginAnnual": 23.97,
#     "netProfitMarginTTM": 24.3,
#     "operatingMargin5Y": 29.11,
#     "operatingMarginAnnual": 31.51,
#     "operatingMarginTTM": 31.81,
#     "payoutRatioAnnual": 16.25,
#     "payoutRatioTTM": 15.74,
#     "pb": 44.9108,
#     "pbAnnual": 61.8474,
#     "pbQuarterly": 50.0084,
#     "pcfShareAnnual": 25.3679,
#     "pcfShareTTM": 27.382,
#     "peAnnual": 32.0033,
#     "peBasicExclExtraTTM": 30.8329,
#     "peExclExtraAnnual": 30.96975,
#     "peExclExtraTTM": 30.8329,
#     "peInclExtraTTM": 30.8329,
#     "peNormalizedAnnual": 32.0033,
#     "peTTM": 30.8329,
#     "pfcfShareAnnual": 27.5705,
#     "pfcfShareTTM": 30.4598,
#     "pretaxMargin5Y": 29.15,
#     "pretaxMarginAnnual": 31.58,
#     "pretaxMarginTTM": 31.72,
#     "priceRelativeToS&P50013Week": -16.1021,
#     "priceRelativeToS&P50026Week": -12.1046,
#     "priceRelativeToS&P5004Week": -6.1843,
#     "priceRelativeToS&P50052Week": -6.4806,
#     "priceRelativeToS&P500Ytd": -20.3595,
#     "psAnnual": 7.6716,
#     "psTTM": 7.4928,
#     "ptbvAnnual": 4.8643,
#     "ptbvQuarterly": 6.4066,
#     "quickRatioAnnual": 0.826,
#     "quickRatioQuarterly": 0.7775,
#     "receivablesTurnoverAnnual": 12.43,
#     "receivablesTurnoverTTM": 16.6913,
#     "revenueEmployeeAnnual": 2.3844,
#     "revenueEmployeeTTM": 2.4413,
#     "revenueGrowth3Y": 2.25,
#     "revenueGrowth5Y": 8.49,
#     "revenueGrowthQuarterlyYoy": 5.08,
#     "revenueGrowthTTMYoy": 4.91,
#     "revenuePerShareAnnual": 25.3785,
#     "revenuePerShareTTM": 26.5916,
#     "revenueShareGrowth5Y": 12.65,
#     "roa5Y": 25.24,
#     "roaRfy": 25.679999999999996,
#     "roaTTM": 28.37,
#     "roe5Y": 151.11,
#     "roeRfy": 164.59,
#     "roeTTM": 151.31,
#     "roi5Y": 50.63,
#     "roiAnnual": 56.989999999999995,
#     "roiTTM": 58.95,
#     "tangibleBookValuePerShareAnnual": 5.8583,
#     "tangibleBookValuePerShareQuarterly": 6.7916,
#     "tbvCagr5Y": 11.34,
#     "totalDebt/totalEquityAnnual": 1.8881,
#     "totalDebt/totalEquityQuarterly": 1.4699,
#     "yearToDatePriceReturnDaily": -19.7947
#   },
#   "metricType": "all",
#   "series": {
#     "annual": {
#       "bookValue": [
#         {
#           "period": "2024-09-28",
#           "v": 56950
#         },
#         {
#           "period": "2023-09-30",
#           "v": 62146
#         },
#         {
#           "period": "2022-09-24",
#           "v": 50672
#         },
#         {
#           "period": "2021-09-25",
#           "v": 63090
#         },
#         {
#           "period": "2020-09-26",
#           "v": 65339
#         },
#         {
#           "period": "2019-09-28",
#           "v": 90488
#         },
#         {
#           "period": "2018-09-29",
#           "v": 107147
#         },
#         {
#           "period": "2017-09-30",
#           "v": 134047
#         },
#         {
#           "period": "2016-09-24",
#           "v": 128249
#         },
#         {
#           "period": "2015-09-26",
#           "v": 119355
#         },
#         {
#           "period": "2014-09-27",
#           "v": 111547
#         },
#         {
#           "period": "2013-09-28",
#           "v": 123549
#         },
#         {
#           "period": "2012-09-29",
#           "v": 118210
#         },
#         {
#           "period": "2011-09-24",
#           "v": 76615
#         },
#         {
#           "period": "2010-09-25",
#           "v": 47791
#         },
#         {
#           "period": "2009-09-26",
#           "v": 31640
#         },
#         {
#           "period": "2008-09-27",
#           "v": 22297
#         },
#         {
#           "period": "2007-09-29",
#           "v": 14532
#         },
#         {
#           "period": "2006-09-30",
#           "v": 9984
#         },
#         {
#           "period": "2005-09-24",
#           "v": 7428
#         },
#         {
#           "period": "2004-09-25",
#           "v": 5076
#         },
#         {
#           "period": "2003-09-27",
#           "v": 4223
#         },
#         {
#           "period": "2002-09-28",
#           "v": 4095
#         },
#         {
#           "period": "2001-09-29",
#           "v": 3920
#         },
#         {
#           "period": "2000-09-30",
#           "v": 4107
#         }
#       ],
#       "cashRatio": [
#         {
#           "period": "2024-09-28",
#           "v": 0.16975259648963673
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.20621713876730807
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.15356340351469652
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.2784485300563432
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.36071049035979963
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.46202160464632325
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.22352474359306126
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.2012518102644474
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2592714477381465
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2620022329735765
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.21819442693229102
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.3266068074579688
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.27881272378184835
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.35091169109760456
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.5434321011485378
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.45741352337910657
#         },
#         {
#           "period": "2008-09-27",
#           "v": 1.045242496259132
#         },
#         {
#           "period": "2007-09-29",
#           "v": 1.0077586206896552
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.9920844327176781
#         },
#         {
#           "period": "2005-09-24",
#           "v": 1.0011471178663607
#         },
#         {
#           "period": "2004-09-25",
#           "v": 1.119954734062618
#         },
#         {
#           "period": "2003-09-27",
#           "v": 1.4408145948239288
#         },
#         {
#           "period": "2002-09-28",
#           "v": 1.3582629674306392
#         },
#         {
#           "period": "2001-09-29",
#           "v": 1.5217391304347827
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.6161407139161924
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.856036152356359
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.9743421052631579
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.6765676567656765
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.7748377433849226
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.3251612903225806
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.6189810754999858
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.2696930127966157
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.3497369380997811
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.49640236933374204
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.3648120110412782
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.48958774321608767
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.4502033024097653
#         },
#         {
#           "period": "1987-09-25",
#           "v": 1.1805305445414247
#         },
#         {
#           "period": "1986-09-26",
#           "v": 1.7538922793614073
#         },
#         {
#           "period": "1985-09-27",
#           "v": 1.1407734619615806
#         }
#       ],
#       "currentRatio": [
#         {
#           "period": "2024-09-28",
#           "v": 0.8673
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.988
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.8794
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.0746
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.3636
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1.5401
#         },
#         {
#           "period": "2018-09-29",
#           "v": 1.1329
#         },
#         {
#           "period": "2017-09-30",
#           "v": 1.2761
#         },
#         {
#           "period": "2016-09-24",
#           "v": 1.3527
#         },
#         {
#           "period": "2015-09-26",
#           "v": 1.1088
#         },
#         {
#           "period": "2014-09-27",
#           "v": 1.0801
#         },
#         {
#           "period": "2013-09-28",
#           "v": 1.6786
#         },
#         {
#           "period": "2012-09-29",
#           "v": 1.4958
#         },
#         {
#           "period": "2011-09-24",
#           "v": 1.6084
#         },
#         {
#           "period": "2010-09-25",
#           "v": 2.0113
#         },
#         {
#           "period": "2009-09-26",
#           "v": 2.7425
#         },
#         {
#           "period": "2008-09-27",
#           "v": 2.6411
#         },
#         {
#           "period": "2007-09-29",
#           "v": 2.3659
#         },
#         {
#           "period": "2006-09-30",
#           "v": 2.2519
#         },
#         {
#           "period": "2005-09-24",
#           "v": 2.9538
#         },
#         {
#           "period": "2004-09-25",
#           "v": 2.6613
#         },
#         {
#           "period": "2003-09-27",
#           "v": 2.4977
#         },
#         {
#           "period": "2002-09-28",
#           "v": 3.2497
#         },
#         {
#           "period": "2001-09-29",
#           "v": 3.388
#         },
#         {
#           "period": "2000-09-30",
#           "v": 2.8076
#         },
#         {
#           "period": "1999-09-25",
#           "v": 2.7663
#         },
#         {
#           "period": "1998-09-25",
#           "v": 2.4329
#         },
#         {
#           "period": "1997-09-26",
#           "v": 1.8834
#         },
#         {
#           "period": "1996-09-27",
#           "v": 2.2541
#         },
#         {
#           "period": "1995-09-29",
#           "v": 2.2469
#         },
#         {
#           "period": "1994-09-30",
#           "v": 2.3023
#         },
#         {
#           "period": "1993-09-24",
#           "v": 1.7297
#         },
#         {
#           "period": "1992-09-25",
#           "v": 2.4962
#         },
#         {
#           "period": "1991-09-27",
#           "v": 2.3529
#         },
#         {
#           "period": "1990-09-28",
#           "v": 2.34
#         },
#         {
#           "period": "1989-09-29",
#           "v": 2.5629
#         },
#         {
#           "period": "1988-09-30",
#           "v": 2.1557
#         },
#         {
#           "period": "1987-09-25",
#           "v": 2.7313
#         },
#         {
#           "period": "1986-09-26",
#           "v": 3.1684
#         },
#         {
#           "period": "1985-09-27",
#           "v": 2.7827
#         }
#       ],
#       "ebitPerShare": [
#         {
#           "period": "2024-09-28",
#           "v": 7.9968
#         },
#         {
#           "period": "2023-09-30",
#           "v": 7.2285
#         },
#         {
#           "period": "2022-09-24",
#           "v": 7.3158
#         },
#         {
#           "period": "2021-09-25",
#           "v": 6.4601
#         },
#         {
#           "period": "2020-09-26",
#           "v": 3.7818
#         },
#         {
#           "period": "2019-09-28",
#           "v": 3.4379
#         },
#         {
#           "period": "2018-09-29",
#           "v": 3.5448
#         },
#         {
#           "period": "2017-09-30",
#           "v": 2.9202
#         },
#         {
#           "period": "2016-09-24",
#           "v": 2.7282
#         },
#         {
#           "period": "2015-09-26",
#           "v": 3.0739
#         },
#         {
#           "period": "2014-09-27",
#           "v": 2.1438
#         },
#         {
#           "period": "2013-09-28",
#           "v": 1.8784
#         },
#         {
#           "period": "2012-09-29",
#           "v": 2.087
#         },
#         {
#           "period": "2011-09-24",
#           "v": 1.2884
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.7101
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.4623
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.3297
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.177
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.0998
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.0685
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0144
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0008
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.0178
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0259
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0184
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.0139
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.0758
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.0998
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0496
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0393
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0083
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0587
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.0332
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0505
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.044
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.0426
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.0252
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.019
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.0074
#         }
#       ],
#       "eps": [
#         {
#           "period": "2024-09-28",
#           "v": 6.0836
#         },
#         {
#           "period": "2023-09-30",
#           "v": 6.1341
#         },
#         {
#           "period": "2022-09-24",
#           "v": 6.1132
#         },
#         {
#           "period": "2021-09-25",
#           "v": 5.614
#         },
#         {
#           "period": "2020-09-26",
#           "v": 3.2753
#         },
#         {
#           "period": "2019-09-28",
#           "v": 2.9714
#         },
#         {
#           "period": "2018-09-29",
#           "v": 2.9765
#         },
#         {
#           "period": "2017-09-30",
#           "v": 2.3017
#         },
#         {
#           "period": "2016-09-24",
#           "v": 2.0766
#         },
#         {
#           "period": "2015-09-26",
#           "v": 2.3042
#         },
#         {
#           "period": "2014-09-27",
#           "v": 1.6133
#         },
#         {
#           "period": "2013-09-28",
#           "v": 1.4198
#         },
#         {
#           "period": "2012-09-29",
#           "v": 1.5767
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.9884
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.5412
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.3243
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.2422
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.1404
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.0809
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.0554
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0123
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0034
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0032
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.0013
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.039
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0308
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.0164
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.074
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.0589
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0308
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0233
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0065
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0387
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.023
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0337
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.0315
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.0275
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.0148
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.0107
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.0044
#         }
#       ],
#       "ev": [
#         {
#           "period": "2024-09-28",
#           "v": 3599793.2
#         },
#         {
#           "period": "2023-09-30",
#           "v": 2783970
#         },
#         {
#           "period": "2022-09-24",
#           "v": 2501154.2
#         },
#         {
#           "period": "2021-09-25",
#           "v": 2493617
#         },
#         {
#           "period": "2020-09-26",
#           "v": 2041191
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1071363
#         },
#         {
#           "period": "2018-09-29",
#           "v": 1186220
#         },
#         {
#           "period": "2017-09-30",
#           "v": 889855
#         },
#         {
#           "period": "2016-09-24",
#           "v": 674795
#         },
#         {
#           "period": "2015-09-26",
#           "v": 670483
#         },
#         {
#           "period": "2014-09-27",
#           "v": 608712
#         },
#         {
#           "period": "2013-09-28",
#           "v": 435827
#         },
#         {
#           "period": "2012-09-29",
#           "v": 607370
#         },
#         {
#           "period": "2011-09-24",
#           "v": 364842
#         },
#         {
#           "period": "2010-09-25",
#           "v": 254736
#         },
#         {
#           "period": "2009-09-26",
#           "v": 161495
#         },
#         {
#           "period": "2008-09-27",
#           "v": 81372.3
#         },
#         {
#           "period": "2007-09-29",
#           "v": 126607
#         },
#         {
#           "period": "2006-09-30",
#           "v": 57277
#         },
#         {
#           "period": "2005-09-24",
#           "v": 41187
#         },
#         {
#           "period": "2004-09-25",
#           "v": 11589.8
#         },
#         {
#           "period": "2003-09-27",
#           "v": 4629.27
#         },
#         {
#           "period": "2002-09-28",
#           "v": 3267.85
#         },
#         {
#           "period": "2001-09-29",
#           "v": 3384.29
#         },
#         {
#           "period": "2000-09-30",
#           "v": 6989.5
#         }
#       ],
#       "fcfMargin": [
#         {
#           "period": "2024-09-28",
#           "v": 0.2783
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.2598
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.2826
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.2541
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.2673
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2264
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.2414
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.2259
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2481
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2986
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.273
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.2609
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.2649
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.2779
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.2526
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.2085
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.224
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.1824
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.0809
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.1633
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0916
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0201
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0909
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.1224
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.121
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.0347
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0628
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.1025
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.1331
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.0508
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.037
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.0383
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.1307
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.1099
#         }
#       ],
#       "grossMargin": [
#         {
#           "period": "2024-09-28",
#           "v": 0.4621
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.4413
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.4331
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.4178
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.3823
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.3782
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.3834
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.3847
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.3908
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.4006
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.3859
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.3762
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.4387
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.4048
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.3938
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.4014
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.352
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.3317
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.2898
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.2901
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.2726
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.2752
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.2792
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.2303
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.2713
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.2765
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.2489
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.1932
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.0984
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.2584
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.2551
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.342
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.4368
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.4747
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.5311
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.49
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.511
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.5129
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.5315
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.4173
#         }
#       ],
#       "inventoryTurnover": [
#         {
#           "period": "2024-09-28",
#           "v": 30.8955
#         },
#         {
#           "period": "2023-09-30",
#           "v": 37.9777
#         },
#         {
#           "period": "2022-09-24",
#           "v": 38.7899
#         },
#         {
#           "period": "2021-09-25",
#           "v": 40.0303
#         },
#         {
#           "period": "2020-09-26",
#           "v": 41.523
#         },
#         {
#           "period": "2019-09-28",
#           "v": 40.1345
#         },
#         {
#           "period": "2018-09-29",
#           "v": 37.1708
#         },
#         {
#           "period": "2017-09-30",
#           "v": 40.3744
#         },
#         {
#           "period": "2016-09-24",
#           "v": 58.6369
#         },
#         {
#           "period": "2015-09-26",
#           "v": 62.8202
#         },
#         {
#           "period": "2014-09-27",
#           "v": 57.9396
#         },
#         {
#           "period": "2013-09-28",
#           "v": 83.4489
#         },
#         {
#           "period": "2012-09-29",
#           "v": 112.12
#         },
#         {
#           "period": "2011-09-24",
#           "v": 70.532
#         },
#         {
#           "period": "2010-09-25",
#           "v": 52.5113
#         },
#         {
#           "period": "2009-09-26",
#           "v": 53.2842
#         },
#         {
#           "period": "2008-09-27",
#           "v": 56.8281
#         },
#         {
#           "period": "2007-09-29",
#           "v": 53.3312
#         },
#         {
#           "period": "2006-09-30",
#           "v": 63.0667
#         },
#         {
#           "period": "2005-09-24",
#           "v": 74.3534
#         },
#         {
#           "period": "2004-09-25",
#           "v": 76.7134
#         },
#         {
#           "period": "2003-09-27",
#           "v": 89.0891
#         },
#         {
#           "period": "2002-09-28",
#           "v": 147.8214
#         },
#         {
#           "period": "2001-09-29",
#           "v": 187.6364
#         },
#         {
#           "period": "2000-09-30",
#           "v": 219.5094
#         },
#         {
#           "period": "1999-09-25",
#           "v": 90.5714
#         },
#         {
#           "period": "1998-09-25",
#           "v": 17.3282
#         },
#         {
#           "period": "1997-09-26",
#           "v": 10.3967
#         },
#         {
#           "period": "1996-09-27",
#           "v": 7.2753
#         },
#         {
#           "period": "1995-09-29",
#           "v": 5.7302
#         },
#         {
#           "period": "1994-09-30",
#           "v": 5.2753
#         },
#         {
#           "period": "1993-09-24",
#           "v": 5.0307
#         },
#         {
#           "period": "1992-09-25",
#           "v": 6.3772
#         },
#         {
#           "period": "1991-09-27",
#           "v": 6.4532
#         },
#         {
#           "period": "1990-09-28",
#           "v": 6.2736
#         },
#         {
#           "period": "1989-09-29",
#           "v": 9.5546
#         },
#         {
#           "period": "1988-09-30",
#           "v": 12.662
#         }
#       ],
#       "longtermDebtTotalAsset": [
#         {
#           "period": "2024-09-28",
#           "v": 0.2349
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.2702
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.2805
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.3108
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.3046
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2712
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.2563
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.259
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2345
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.1837
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.125
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.0819
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0502
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0526
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0441
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0581
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.2224
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.2247
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.1769
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0486
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0574
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0014
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0
#         }
#       ],
#       "longtermDebtTotalCapital": [
#         {
#           "period": "2024-09-28",
#           "v": 0.5214
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.5468
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.5764
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.5783
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.553
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.4624
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.4229
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.3893
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.3504
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2903
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.1974
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.1207
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0716
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0748
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0681
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0881
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.3675
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.437
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.2972
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0827
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.1022
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0025
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0
#         }
#       ],
#       "longtermDebtTotalEquity": [
#         {
#           "period": "2024-09-28",
#           "v": 1.5057
#         },
#         {
#           "period": "2023-09-30",
#           "v": 1.5332
#         },
#         {
#           "period": "2022-09-24",
#           "v": 1.9529
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.7294
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.5101
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1.0146
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.8748
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.7252
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.5881
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.4468
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.2599
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.1373
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0772
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0809
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.073
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0966
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.581
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.7925
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.4611
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.1044
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.1278
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0035
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0
#         }
#       ],
#       "netDebtToTotalCapital": [
#         {
#           "period": "2024-09-28",
#           "v": 0.4717
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.4714
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.5671
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.4804
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.4208
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2982
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.3996
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.382
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.3091
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2352
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.1461
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.0192
#         },
#         {
#           "period": "2012-09-29",
#           "v": -0.0909
#         },
#         {
#           "period": "2011-09-24",
#           "v": -0.1281
#         },
#         {
#           "period": "2010-09-25",
#           "v": -0.2356
#         },
#         {
#           "period": "2009-09-26",
#           "v": -0.1663
#         },
#         {
#           "period": "2008-09-27",
#           "v": -0.5326
#         },
#         {
#           "period": "2007-09-29",
#           "v": -0.6435
#         },
#         {
#           "period": "2006-09-30",
#           "v": -0.6402
#         },
#         {
#           "period": "2005-09-24",
#           "v": -0.47
#         },
#         {
#           "period": "2004-09-25",
#           "v": -0.5849
#         },
#         {
#           "period": "2003-09-27",
#           "v": -0.683
#         },
#         {
#           "period": "2002-09-28",
#           "v": -0.4389
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.4704
#         },
#         {
#           "period": "2000-09-30",
#           "v": -0.2022
#         },
#         {
#           "period": "1999-09-25",
#           "v": -0.3014
#         },
#         {
#           "period": "1998-09-25",
#           "v": -0.203
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.1167
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.1306
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0022
#         },
#         {
#           "period": "1994-09-30",
#           "v": -0.2036
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0539
#         },
#         {
#           "period": "1992-09-25",
#           "v": -0.1324
#         },
#         {
#           "period": "1991-09-27",
#           "v": -0.2379
#         },
#         {
#           "period": "1990-09-28",
#           "v": -0.1606
#         },
#         {
#           "period": "1989-09-29",
#           "v": -0.2474
#         },
#         {
#           "period": "1988-09-30",
#           "v": -0.0438
#         },
#         {
#           "period": "1987-09-25",
#           "v": -0.6756
#         },
#         {
#           "period": "1986-09-26",
#           "v": -0.8302
#         },
#         {
#           "period": "1985-09-27",
#           "v": -0.6122
#         }
#       ],
#       "netDebtToTotalEquity": [
#         {
#           "period": "2024-09-28",
#           "v": 1.3623
#         },
#         {
#           "period": "2023-09-30",
#           "v": 1.3218
#         },
#         {
#           "period": "2022-09-24",
#           "v": 1.9215
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.4365
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.1491
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.6543
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.8266
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.7116
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.5189
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.362
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.1923
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.0219
#         },
#         {
#           "period": "2012-09-29",
#           "v": -0.0909
#         },
#         {
#           "period": "2011-09-24",
#           "v": -0.1281
#         },
#         {
#           "period": "2010-09-25",
#           "v": -0.2356
#         },
#         {
#           "period": "2009-09-26",
#           "v": -0.1663
#         },
#         {
#           "period": "2008-09-27",
#           "v": -0.5326
#         },
#         {
#           "period": "2007-09-29",
#           "v": -0.6435
#         },
#         {
#           "period": "2006-09-30",
#           "v": -0.6402
#         },
#         {
#           "period": "2005-09-24",
#           "v": -0.47
#         },
#         {
#           "period": "2004-09-25",
#           "v": -0.5849
#         },
#         {
#           "period": "2003-09-27",
#           "v": -0.7322
#         },
#         {
#           "period": "2002-09-28",
#           "v": -0.4728
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.5084
#         },
#         {
#           "period": "2000-09-30",
#           "v": -0.2169
#         },
#         {
#           "period": "1999-09-25",
#           "v": -0.3305
#         },
#         {
#           "period": "1998-09-25",
#           "v": -0.321
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.2117
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.2026
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0028
#         },
#         {
#           "period": "1994-09-30",
#           "v": -0.2546
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0759
#         },
#         {
#           "period": "1992-09-25",
#           "v": -0.1436
#         },
#         {
#           "period": "1991-09-27",
#           "v": -0.2579
#         },
#         {
#           "period": "1990-09-28",
#           "v": -0.1742
#         },
#         {
#           "period": "1989-09-29",
#           "v": -0.2568
#         },
#         {
#           "period": "1988-09-30",
#           "v": -0.0575
#         },
#         {
#           "period": "1987-09-25",
#           "v": -0.6756
#         },
#         {
#           "period": "1986-09-26",
#           "v": -0.8302
#         },
#         {
#           "period": "1985-09-27",
#           "v": -0.6122
#         }
#       ],
#       "netMargin": [
#         {
#           "period": "2024-09-28",
#           "v": 0.2397
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.2531
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.2531
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.2588
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.2091
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2124
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.2241
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.2109
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2119
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2285
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.2161
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.2167
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.2667
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.2395
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.2148
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.1919
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.1632
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.1422
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.103
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.0953
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0321
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0111
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0113
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.0047
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0985
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.098
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.052
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.1476
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.083
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0383
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0338
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0109
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0748
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.0491
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0854
#         },
#         {
# ...
#           "v": 0
#         },
#         {
#           "period": "2005-06-25",
#           "v": 0
#         },
#         {
#           "period": "2005-03-26",
#           "v": 0
#         },
#         {
#           "period": "2004-12-25",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2004-06-26",
#           "v": 0
#         },
#         {
#           "period": "2004-03-27",
#           "v": 0
#         },
#         {
#           "period": "2003-12-27",
#           "v": 0.0652
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0672
#         },
#         {
#           "period": "2003-06-28",
#           "v": 0.0681
#         },
#         {
#           "period": "2003-03-29",
#           "v": 0.0697
#         },
#         {
#           "period": "2002-12-28",
#           "v": 0.0721
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0716
#         },
#         {
#           "period": "2002-06-29",
#           "v": 0.0721
#         },
#         {
#           "period": "2002-03-30",
#           "v": 0.0719
#         },
#         {
#           "period": "2001-12-29",
#           "v": 0.0736
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0748
#         },
#         {
#           "period": "2001-06-30",
#           "v": 0.0759
#         },
#         {
#           "period": "2001-03-31",
#           "v": 0.0782
#         },
#         {
#           "period": "2000-12-30",
#           "v": 0.0773
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0681
#         },
#         {
#           "period": "2000-07-01",
#           "v": 0.067
#         },
#         {
#           "period": "2000-04-01",
#           "v": 0.0664
#         },
#         {
#           "period": "2000-01-01",
#           "v": 0.0636
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0881
#         },
#         {
#           "period": "1999-06-26",
#           "v": 0.0917
#         },
#         {
#           "period": "1999-03-27",
#           "v": 0.3051
#         },
#         {
#           "period": "1998-12-26",
#           "v": 0.3316
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.3675
#         },
#         {
#           "period": "1998-06-26",
#           "v": 0.3907
#         },
#         {
#           "period": "1998-03-27",
#           "v": 0.4129
#         },
#         {
#           "period": "1997-12-26",
#           "v": 0.4396
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.4485
#         },
#         {
#           "period": "1997-06-27",
#           "v": 0.4741
#         },
#         {
#           "period": "1997-03-28",
#           "v": 0.4663
#         },
#         {
#           "period": "1996-12-27",
#           "v": 0.3678
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.3555
#         },
#         {
#           "period": "1996-06-28",
#           "v": 0.3599
#         },
#         {
#           "period": "1996-03-29",
#           "v": 0.2416
#         },
#         {
#           "period": "1995-12-29",
#           "v": 0.223
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.2085
#         },
#         {
#           "period": "1995-06-30",
#           "v": 0.2005
#         },
#         {
#           "period": "1995-03-31",
#           "v": 0.2554
#         },
#         {
#           "period": "1994-12-30",
#           "v": 0.1668
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.2002
#         },
#         {
#           "period": "1994-07-01",
#           "v": 0.2676
#         },
#         {
#           "period": "1994-04-01",
#           "v": 0.2739
#         },
#         {
#           "period": "1993-12-31",
#           "v": 0.2681
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.2907
#         },
#         {
#           "period": "1993-06-25",
#           "v": 0.1323
#         },
#         {
#           "period": "1993-03-26",
#           "v": 0.0255
#         },
#         {
#           "period": "1992-12-25",
#           "v": 0.0771
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0778
#         },
#         {
#           "period": "1992-06-26",
#           "v": 0.0783
#         },
#         {
#           "period": "1992-03-27",
#           "v": 0.0613
#         },
#         {
#           "period": "1991-12-27",
#           "v": 0.0232
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.0776
#         },
#         {
#           "period": "1991-06-28",
#           "v": 0.0858
#         },
#         {
#           "period": "1991-03-29",
#           "v": 0.0033
#         },
#         {
#           "period": "1990-12-28",
#           "v": 0.0147
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0781
#         },
#         {
#           "period": "1990-06-29",
#           "v": 0.0163
#         },
#         {
#           "period": "1990-03-30",
#           "v": 0.0127
#         },
#         {
#           "period": "1989-12-29",
#           "v": 0.0427
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.0368
#         }
#       ],
#       "totalRatio": [
#         {
#           "period": "2025-03-29",
#           "v": 1.2526
#         },
#         {
#           "period": "2024-12-28",
#           "v": 1.2407
#         },
#         {
#           "period": "2024-09-28",
#           "v": 1.1849
#         },
#         {
#           "period": "2024-06-29",
#           "v": 1.2518
#         },
#         {
#           "period": "2024-03-30",
#           "v": 1.2819
#         },
#         {
#           "period": "2023-12-30",
#           "v": 1.2652
#         },
#         {
#           "period": "2023-09-30",
#           "v": 1.214
#         },
#         {
#           "period": "2023-07-01",
#           "v": 1.2194
#         },
#         {
#           "period": "2023-04-01",
#           "v": 1.2302
#         },
#         {
#           "period": "2022-12-31",
#           "v": 1.1956
#         },
#         {
#           "period": "2022-09-24",
#           "v": 1.1677
#         },
#         {
#           "period": "2022-06-25",
#           "v": 1.2089
#         },
#         {
#           "period": "2022-03-26",
#           "v": 1.2379
#         },
#         {
#           "period": "2021-12-25",
#           "v": 1.2326
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.2191
#         },
#         {
#           "period": "2021-06-26",
#           "v": 1.2421
#         },
#         {
#           "period": "2021-03-27",
#           "v": 1.2581
#         },
#         {
#           "period": "2020-12-26",
#           "v": 1.2301
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.2527
#         },
#         {
#           "period": "2020-06-27",
#           "v": 1.295
#         },
#         {
#           "period": "2020-03-28",
#           "v": 1.3241
#         },
#         {
#           "period": "2019-12-28",
#           "v": 1.3566
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1.3648
#         },
#         {
#           "period": "2019-06-29",
#           "v": 1.4272
#         },
#         {
#           "period": "2019-03-30",
#           "v": 1.4483
#         },
#         {
#           "period": "2018-12-29",
#           "v": 1.4608
#         },
#         {
#           "period": "2018-09-29",
#           "v": 1.4144
#         },
#         {
#           "period": "2018-06-30",
#           "v": 1.4907
#         },
#         {
#           "period": "2018-03-31",
#           "v": 1.5273
#         },
#         {
#           "period": "2017-12-30",
#           "v": 1.5259
#         },
#         {
#           "period": "2017-09-30",
#           "v": 1.5556
#         },
#         {
#           "period": "2017-07-01",
#           "v": 1.6225
#         },
#         {
#           "period": "2017-04-01",
#           "v": 1.6689
#         },
#         {
#           "period": "2016-12-31",
#           "v": 1.6661
#         },
#         {
#           "period": "2016-09-24",
#           "v": 1.663
#         },
#         {
#           "period": "2016-06-25",
#           "v": 1.7067
#         },
#         {
#           "period": "2016-03-26",
#           "v": 1.7462
#         },
#         {
#           "period": "2015-12-26",
#           "v": 1.7773
#         },
#         {
#           "period": "2015-09-26",
#           "v": 1.698
#         },
#         {
#           "period": "2015-06-27",
#           "v": 1.8522
#         },
#         {
#           "period": "2015-03-28",
#           "v": 1.9759
#         },
#         {
#           "period": "2014-12-27",
#           "v": 1.89
#         },
#         {
#           "period": "2014-09-27",
#           "v": 1.9273
#         },
#         {
#           "period": "2014-06-28",
#           "v": 2.1906
#         },
#         {
#           "period": "2014-03-29",
#           "v": 2.4005
#         },
#         {
#           "period": "2013-12-28",
#           "v": 2.3579
#         },
#         {
#           "period": "2013-09-28",
#           "v": 2.4805
#         },
#         {
#           "period": "2013-06-29",
#           "v": 2.6124
#         },
#         {
#           "period": "2013-03-30",
#           "v": 3.2866
#         },
#         {
#           "period": "2012-12-29",
#           "v": 2.8525
#         },
#         {
#           "period": "2012-09-29",
#           "v": 3.0432
#         },
#         {
#           "period": "2012-06-30",
#           "v": 3.1847
#         },
#         {
#           "period": "2012-03-31",
#           "v": 3.1162
#         },
#         {
#           "period": "2011-12-31",
#           "v": 2.8519
#         },
#         {
#           "period": "2011-09-24",
#           "v": 2.9271
#         },
#         {
#           "period": "2011-06-25",
#           "v": 2.8533
#         },
#         {
#           "period": "2011-03-26",
#           "v": 2.8391
#         },
#         {
#           "period": "2010-12-25",
#           "v": 2.7043
#         },
#         {
#           "period": "2010-09-25",
#           "v": 2.7447
#         },
#         {
#           "period": "2010-06-26",
#           "v": 2.9946
#         },
#         {
#           "period": "2010-03-27",
#           "v": 3.2219
#         },
#         {
#           "period": "2009-12-26",
#           "v": 2.9698
#         },
#         {
#           "period": "2009-09-26",
#           "v": 2.9948
#         },
#         {
#           "period": "2009-06-27",
#           "v": 2.1634
#         },
#         {
#           "period": "2009-03-28",
#           "v": 2.2845
#         },
#         {
#           "period": "2008-12-27",
#           "v": 2.1525
#         },
#         {
#           "period": "2008-09-27",
#           "v": 2.6071
#         },
#         {
#           "period": "2008-06-28",
#           "v": 2.6234
#         },
#         {
#           "period": "2008-03-29",
#           "v": 2.4538
#         },
#         {
#           "period": "2007-12-29",
#           "v": 2.2697
#         },
#         {
#           "period": "2007-09-29",
#           "v": 2.3437
#         },
#         {
#           "period": "2007-06-30",
#           "v": 2.6261
#         },
#         {
#           "period": "2007-03-31",
#           "v": 2.9009
#         },
#         {
#           "period": "2006-12-30",
#           "v": 2.3638
#         },
#         {
#           "period": "2006-09-30",
#           "v": 2.3826
#         },
#         {
#           "period": "2006-07-01",
#           "v": 2.6131
#         },
#         {
#           "period": "2006-04-01",
#           "v": 2.6604
#         },
#         {
#           "period": "2005-12-31",
#           "v": 2.4446
#         },
#         {
#           "period": "2005-09-24",
#           "v": 2.817
#         },
#         {
#           "period": "2005-06-25",
#           "v": 2.8601
#         },
#         {
#           "period": "2005-03-26",
#           "v": 2.7144
#         },
#         {
#           "period": "2004-12-25",
#           "v": 2.6209
#         },
#         {
#           "period": "2004-09-25",
#           "v": 2.7068
#         },
#         {
#           "period": "2004-06-26",
#           "v": 2.9959
#         },
#         {
#           "period": "2004-03-27",
#           "v": 3
#         },
#         {
#           "period": "2003-12-27",
#           "v": 2.6395
#         },
#         {
#           "period": "2003-09-27",
#           "v": 2.6292
#         },
#         {
#           "period": "2003-06-28",
#           "v": 2.8716
#         },
#         {
#           "period": "2003-03-29",
#           "v": 2.8627
#         },
#         {
#           "period": "2002-12-28",
#           "v": 2.9118
#         },
#         {
#           "period": "2002-09-28",
#           "v": 2.8588
#         },
#         {
#           "period": "2002-06-29",
#           "v": 2.8258
#         },
#         {
#           "period": "2002-03-30",
#           "v": 2.784
#         },
#         {
#           "period": "2001-12-29",
#           "v": 2.8395
#         },
#         {
#           "period": "2001-09-29",
#           "v": 2.8658
#         },
#         {
#           "period": "2001-06-30",
#           "v": 2.7433
#         },
#         {
#           "period": "2001-03-31",
#           "v": 2.5627
#         },
#         {
#           "period": "2000-12-30",
#           "v": 2.6324
#         },
#         {
#           "period": "2000-09-30",
#           "v": 2.5234
#         },
#         {
#           "period": "2000-07-01",
#           "v": 2.5152
#         },
#         {
#           "period": "2000-04-01",
#           "v": 2.5097
#         },
#         {
#           "period": "2000-01-01",
#           "v": 2.3916
#         },
#         {
#           "period": "1999-09-25",
#           "v": 2.509
#         },
#         {
#           "period": "1999-06-26",
#           "v": 2.4495
#         },
#         {
#           "period": "1999-03-27",
#           "v": 1.788
#         },
#         {
#           "period": "1998-12-26",
#           "v": 1.7205
#         },
#         {
#           "period": "1998-09-25",
#           "v": 1.6203
#         },
#         {
#           "period": "1998-06-26",
#           "v": 1.5816
#         },
#         {
#           "period": "1998-03-27",
#           "v": 1.539
#         },
#         {
#           "period": "1997-12-26",
#           "v": 1.4316
#         },
#         {
#           "period": "1997-09-26",
#           "v": 1.3956
#         },
#         {
#           "period": "1997-06-27",
#           "v": 1.3803
#         },
#         {
#           "period": "1997-03-28",
#           "v": 1.3827
#         },
#         {
#           "period": "1996-12-27",
#           "v": 1.5832
#         },
#         {
#           "period": "1996-09-27",
#           "v": 1.6225
#         },
#         {
#           "period": "1996-06-28",
#           "v": 1.6075
#         },
#         {
#           "period": "1996-03-29",
#           "v": 1.6469
#         },
#         {
#           "period": "1995-12-29",
#           "v": 1.7433
#         },
#         {
#           "period": "1995-09-29",
#           "v": 1.8712
#         },
#         {
#           "period": "1995-06-30",
#           "v": 1.8611
#         },
#         {
#           "period": "1995-03-31",
#           "v": 1.8135
#         },
#         {
#           "period": "1994-12-30",
#           "v": 1.8623
#         },
#         {
#           "period": "1994-09-30",
#           "v": 1.8164
#         },
#         {
#           "period": "1994-07-01",
#           "v": 1.78
#         },
#         {
#           "period": "1994-04-01",
#           "v": 1.6639
#         },
#         {
#           "period": "1993-12-31",
#           "v": 1.6869
#         },
#         {
#           "period": "1993-09-24",
#           "v": 1.6443
#         },
#         {
#           "period": "1993-06-25",
#           "v": 1.7354
#         },
#         {
#           "period": "1993-03-26",
#           "v": 2.0469
#         },
#         {
#           "period": "1992-12-25",
#           "v": 2.0321
#         },
#         {
#           "period": "1992-09-25",
#           "v": 2.0742
#         },
#         {
#           "period": "1992-06-26",
#           "v": 2.0608
#         },
#         {
#           "period": "1992-03-27",
#           "v": 2.1257
#         },
#         {
#           "period": "1991-12-27",
#           "v": 2.0549
#         },
#         {
#           "period": "1991-09-27",
#           "v": 2.023
#         },
#         {
#           "period": "1991-06-28",
#           "v": 1.9314
#         },
#         {
#           "period": "1991-03-29",
#           "v": 2.1285
#         },
#         {
#           "period": "1990-12-28",
#           "v": 1.9584
#         },
#         {
#           "period": "1990-09-28",
#           "v": 1.9463
#         },
#         {
#           "period": "1990-06-29",
#           "v": 2.0898
#         },
#         {
#           "period": "1990-03-30",
#           "v": 2.2663
#         },
#         {
#           "period": "1989-12-29",
#           "v": 2.1817
#         },
#         {
#           "period": "1989-09-29",
#           "v": 2.1809
#         }
#       ]
#     }
#   },
#   "symbol": "AAPL"
# }

# %% [markdown]
# #### `get_basic_financials(...)`
#
# - `basic_financials = finnhub_client.company_basic_financials(symbol, "all")`: 获取所有基本财务数据
#
# - `output_dict = basic_financials["metric"]`: 初始化 `output_dict`，使用从API返回的 `metric` 字段，这通常包含一些最新的、非时间序列的指标值。
#
# - 遍历 `basic_financials["series"]["quarterly"].items()`: 获取最新的季度数据（通常是列表中的第一个元素 value_list[0]），并用这些值更新 output_dict。
#
# - `return json.dumps(output_dict, indent=2)`: 将最终的字典转换为格式化的 JSON 字符串

# %%
print(FinnHubUtils.get_basic_financials("AAPL"))
# Out:
# Finnhub client initialized
# {
#   "10DayAverageTradingVolume": 55.16882,
#   "13WeekPriceReturnDaily": -15.3603,
#   "26WeekPriceReturnDaily": -12.2926,
#   "3MonthADReturnStd": 51.084312,
#   "3MonthAverageTradingVolume": 59.25201,
#   "52WeekHigh": 260.1,
#   "52WeekHighDate": "2024-12-26",
#   "52WeekLow": 169.2101,
#   "52WeekLowDate": "2025-04-08",
#   "52WeekPriceReturnDaily": 5.5494,
#   "5DayPriceReturnDaily": 2.8576,
#   "assetTurnoverAnnual": 1.0714,
#   "assetTurnoverTTM": 1.1673,
#   "beta": 1.2146548,
#   "bookValuePerShareAnnual": 3.7673,
#   "bookValuePerShareQuarterly": 4.4712,
#   "bookValueShareGrowth5Y": -5.85,
#   "capexCagr5Y": -2.08,
#   "cashFlowPerShareAnnual": 7.1978,
#   "cashFlowPerShareQuarterly": 6.5924,
#   "cashFlowPerShareTTM": 6.86253,
#   "cashPerSharePerShareAnnual": 4.3112,
#   "cashPerSharePerShareQuarterly": 3.2463,
#   "currentDividendYieldTTM": 0.5105,
#   "currentEv/freeCashFlowAnnual": 28.214,
#   "currentEv/freeCashFlowTTM": 31.1708,
#   "currentRatioAnnual": 0.8673,
#   "currentRatioQuarterly": 0.8209,
#   "dividendGrowthRate5Y": 5.3,
#   "dividendPerShareAnnual": 0.9935,
#   "dividendPerShareTTM": 1.0115,
#   "dividendYieldIndicatedAnnual": 0.5177993,
#   "ebitdPerShareAnnual": 8.7571,
#   "ebitdPerShareTTM": 9.1121,
#   "ebitdaCagr5Y": 11.9,
#   "ebitdaInterimCagr5Y": 15.39,
#   "enterpriseValue": 3069884.8,
#   "epsAnnual": 6.0836,
#   "epsBasicExclExtraItemsAnnual": 6.0836,
#   "epsBasicExclExtraItemsTTM": 6.4078,
#   "epsExclExtraItemsAnnual": 6.0836,
#   "epsExclExtraItemsTTM": 6.4078,
#   "epsGrowth3Y": 2.71,
#   "epsGrowth5Y": 15.41,
#   "epsGrowthQuarterlyYoy": 7.68,
#   "epsGrowthTTMYoy": -0.36,
#   "epsInclExtraItemsAnnual": 6.0836,
#   "epsInclExtraItemsTTM": 6.4078,
#   "epsNormalizedAnnual": 6.0836,
#   "epsTTM": 6.4078,
#   "focfCagr5Y": 13.06,
#   "grossMargin5Y": 42.73,
#   "grossMarginAnnual": 46.21,
#   "grossMarginTTM": 46.63,
#   "inventoryTurnoverAnnual": 30.8955,
#   "inventoryTurnoverTTM": 34.184,
#   "longTermDebt/equityAnnual": 1.5057,
#   "longTermDebt/equityQuarterly": 1.1762,
#   "marketCapitalization": 2999860.8,
#   "monthToDatePriceReturnDaily": -5.4824,
#   "netIncomeEmployeeAnnual": 0.5716,
#   "netIncomeEmployeeTTM": 0.5933,
#   "netInterestCoverageAnnual": 622.5082,
#   "netInterestCoverageTTM": 622.5082,
#   "netMarginGrowth5Y": 2.45,
#   "netProfitMargin5Y": 24.28,
#   "netProfitMarginAnnual": 23.97,
#   "netProfitMarginTTM": 24.3,
#   "operatingMargin5Y": 29.11,
#   "operatingMarginAnnual": 31.51,
#   "operatingMarginTTM": 31.81,
#   "payoutRatioAnnual": 16.25,
#   "payoutRatioTTM": 0.1574,
#   "pb": 50.0084,
#   "pbAnnual": 61.8474,
#   "pbQuarterly": 50.0084,
#   "pcfShareAnnual": 25.3679,
#   "pcfShareTTM": 27.382,
#   "peAnnual": 32.0033,
#   "peBasicExclExtraTTM": 30.8329,
#   "peExclExtraAnnual": 30.96975,
#   "peExclExtraTTM": 30.8329,
#   "peInclExtraTTM": 30.8329,
#   "peNormalizedAnnual": 32.0033,
#   "peTTM": 34.3327,
#   "pfcfShareAnnual": 27.5705,
#   "pfcfShareTTM": 30.4598,
#   "pretaxMargin5Y": 29.15,
#   "pretaxMarginAnnual": 31.58,
#   "pretaxMarginTTM": 31.72,
#   "priceRelativeToS&P50013Week": -16.1021,
#   "priceRelativeToS&P50026Week": -12.1046,
#   "priceRelativeToS&P5004Week": -6.1843,
#   "priceRelativeToS&P50052Week": -6.4806,
#   "priceRelativeToS&P500Ytd": -20.3595,
#   "psAnnual": 7.6716,
#   "psTTM": 8.3433,
#   "ptbvAnnual": 4.8643,
#   "ptbvQuarterly": 6.4066,
#   "quickRatioAnnual": 0.826,
#   "quickRatioQuarterly": 0.7775,
#   "receivablesTurnoverAnnual": 12.43,
#   "receivablesTurnoverTTM": 16.6913,
#   "revenueEmployeeAnnual": 2.3844,
#   "revenueEmployeeTTM": 2.4413,
#   "revenueGrowth3Y": 2.25,
#   "revenueGrowth5Y": 8.49,
#   "revenueGrowthQuarterlyYoy": 5.08,
#   "revenueGrowthTTMYoy": 4.91,
#   "revenuePerShareAnnual": 25.3785,
#   "revenuePerShareTTM": 26.5916,
#   "revenueShareGrowth5Y": 12.65,
#   "roa5Y": 25.24,
#   "roaRfy": 25.679999999999996,
#   "roaTTM": 0.2837,
#   "roe5Y": 151.11,
#   "roeRfy": 164.59,
#   "roeTTM": 1.5131,
#   "roi5Y": 50.63,
#   "roiAnnual": 56.989999999999995,
#   "roiTTM": 58.95,
#   "tangibleBookValuePerShareAnnual": 5.8583,
#   "tangibleBookValuePerShareQuarterly": 6.7916,
#   "tbvCagr5Y": 11.34,
#   "totalDebt/totalEquityAnnual": 1.8881,
#   "totalDebt/totalEquityQuarterly": 1.4699,
#   "yearToDatePriceReturnDaily": -19.7947,
#   "bookValue": 66796,
#   "cashRatio": 0.19479702014926922,
#   "currentRatio": 0.8209,
#   "ebitPerShare": 1.9652,
#   "eps": 1.6458,
#   "ev": 3410387,
#   "fcfMargin": 0.219,
#   "fcfPerShareTTM": 6.5924,
#   "grossMargin": 0.4705,
#   "longtermDebtTotalAsset": 0.2372,
#   "longtermDebtTotalCapital": 0.4762,
#   "longtermDebtTotalEquity": 1.1762,
#   "netDebtToTotalCapital": 0.4244,
#   "netDebtToTotalEquity": 1.0483,
#   "netMargin": 0.2599,
#   "operatingMargin": 0.3103,
#   "pfcfTTM": 33.9171,
#   "pretaxMargin": 0.3074,
#   "ptbv": 6.4066,
#   "quickRatio": 0.7775,
#   "roicTTM": 0.5895,
#   "rotcTTM": 0.7718,
#   "salesPerShare": 6.3336,
#   "sgaToSale": 0.5295,
#   "tangibleBookValue": 138050,
#   "totalDebtToEquity": 1.4699,
#   "totalDebtToTotalAsset": 0.2964,
#   "totalDebtToTotalCapital": 0.5951,
#   "totalRatio": 1.2526
# }

# %%
basic_financials = finnhub_client.company_basic_financials("AAPL", "all")

import json
print(json.dumps(basic_financials, indent=2))
# Out:
# {
#   "metric": {
#     "10DayAverageTradingVolume": 55.16882,
#     "13WeekPriceReturnDaily": -15.3603,
#     "26WeekPriceReturnDaily": -12.2926,
#     "3MonthADReturnStd": 51.084312,
#     "3MonthAverageTradingVolume": 59.25201,
#     "52WeekHigh": 260.1,
#     "52WeekHighDate": "2024-12-26",
#     "52WeekLow": 169.2101,
#     "52WeekLowDate": "2025-04-08",
#     "52WeekPriceReturnDaily": 5.5494,
#     "5DayPriceReturnDaily": 2.8576,
#     "assetTurnoverAnnual": 1.0714,
#     "assetTurnoverTTM": 1.1673,
#     "beta": 1.2146548,
#     "bookValuePerShareAnnual": 3.7673,
#     "bookValuePerShareQuarterly": 4.4712,
#     "bookValueShareGrowth5Y": -5.85,
#     "capexCagr5Y": -2.08,
#     "cashFlowPerShareAnnual": 7.1978,
#     "cashFlowPerShareQuarterly": 6.5924,
#     "cashFlowPerShareTTM": 6.86253,
#     "cashPerSharePerShareAnnual": 4.3112,
#     "cashPerSharePerShareQuarterly": 3.2463,
#     "currentDividendYieldTTM": 0.5105,
#     "currentEv/freeCashFlowAnnual": 28.214,
#     "currentEv/freeCashFlowTTM": 31.1708,
#     "currentRatioAnnual": 0.8673,
#     "currentRatioQuarterly": 0.8209,
#     "dividendGrowthRate5Y": 5.3,
#     "dividendPerShareAnnual": 0.9935,
#     "dividendPerShareTTM": 1.0115,
#     "dividendYieldIndicatedAnnual": 0.5177993,
#     "ebitdPerShareAnnual": 8.7571,
#     "ebitdPerShareTTM": 9.1121,
#     "ebitdaCagr5Y": 11.9,
#     "ebitdaInterimCagr5Y": 15.39,
#     "enterpriseValue": 3069884.8,
#     "epsAnnual": 6.0836,
#     "epsBasicExclExtraItemsAnnual": 6.0836,
#     "epsBasicExclExtraItemsTTM": 6.4078,
#     "epsExclExtraItemsAnnual": 6.0836,
#     "epsExclExtraItemsTTM": 6.4078,
#     "epsGrowth3Y": 2.71,
#     "epsGrowth5Y": 15.41,
#     "epsGrowthQuarterlyYoy": 7.68,
#     "epsGrowthTTMYoy": -0.36,
#     "epsInclExtraItemsAnnual": 6.0836,
#     "epsInclExtraItemsTTM": 6.4078,
#     "epsNormalizedAnnual": 6.0836,
#     "epsTTM": 6.4078,
#     "focfCagr5Y": 13.06,
#     "grossMargin5Y": 42.73,
#     "grossMarginAnnual": 46.21,
#     "grossMarginTTM": 46.63,
#     "inventoryTurnoverAnnual": 30.8955,
#     "inventoryTurnoverTTM": 34.184,
#     "longTermDebt/equityAnnual": 1.5057,
#     "longTermDebt/equityQuarterly": 1.1762,
#     "marketCapitalization": 2999860.8,
#     "monthToDatePriceReturnDaily": -5.4824,
#     "netIncomeEmployeeAnnual": 0.5716,
#     "netIncomeEmployeeTTM": 0.5933,
#     "netInterestCoverageAnnual": 622.5082,
#     "netInterestCoverageTTM": 622.5082,
#     "netMarginGrowth5Y": 2.45,
#     "netProfitMargin5Y": 24.28,
#     "netProfitMarginAnnual": 23.97,
#     "netProfitMarginTTM": 24.3,
#     "operatingMargin5Y": 29.11,
#     "operatingMarginAnnual": 31.51,
#     "operatingMarginTTM": 31.81,
#     "payoutRatioAnnual": 16.25,
#     "payoutRatioTTM": 15.74,
#     "pb": 44.9108,
#     "pbAnnual": 61.8474,
#     "pbQuarterly": 50.0084,
#     "pcfShareAnnual": 25.3679,
#     "pcfShareTTM": 27.382,
#     "peAnnual": 32.0033,
#     "peBasicExclExtraTTM": 30.8329,
#     "peExclExtraAnnual": 30.96975,
#     "peExclExtraTTM": 30.8329,
#     "peInclExtraTTM": 30.8329,
#     "peNormalizedAnnual": 32.0033,
#     "peTTM": 30.8329,
#     "pfcfShareAnnual": 27.5705,
#     "pfcfShareTTM": 30.4598,
#     "pretaxMargin5Y": 29.15,
#     "pretaxMarginAnnual": 31.58,
#     "pretaxMarginTTM": 31.72,
#     "priceRelativeToS&P50013Week": -16.1021,
#     "priceRelativeToS&P50026Week": -12.1046,
#     "priceRelativeToS&P5004Week": -6.1843,
#     "priceRelativeToS&P50052Week": -6.4806,
#     "priceRelativeToS&P500Ytd": -20.3595,
#     "psAnnual": 7.6716,
#     "psTTM": 7.4928,
#     "ptbvAnnual": 4.8643,
#     "ptbvQuarterly": 6.4066,
#     "quickRatioAnnual": 0.826,
#     "quickRatioQuarterly": 0.7775,
#     "receivablesTurnoverAnnual": 12.43,
#     "receivablesTurnoverTTM": 16.6913,
#     "revenueEmployeeAnnual": 2.3844,
#     "revenueEmployeeTTM": 2.4413,
#     "revenueGrowth3Y": 2.25,
#     "revenueGrowth5Y": 8.49,
#     "revenueGrowthQuarterlyYoy": 5.08,
#     "revenueGrowthTTMYoy": 4.91,
#     "revenuePerShareAnnual": 25.3785,
#     "revenuePerShareTTM": 26.5916,
#     "revenueShareGrowth5Y": 12.65,
#     "roa5Y": 25.24,
#     "roaRfy": 25.679999999999996,
#     "roaTTM": 28.37,
#     "roe5Y": 151.11,
#     "roeRfy": 164.59,
#     "roeTTM": 151.31,
#     "roi5Y": 50.63,
#     "roiAnnual": 56.989999999999995,
#     "roiTTM": 58.95,
#     "tangibleBookValuePerShareAnnual": 5.8583,
#     "tangibleBookValuePerShareQuarterly": 6.7916,
#     "tbvCagr5Y": 11.34,
#     "totalDebt/totalEquityAnnual": 1.8881,
#     "totalDebt/totalEquityQuarterly": 1.4699,
#     "yearToDatePriceReturnDaily": -19.7947
#   },
#   "metricType": "all",
#   "series": {
#     "annual": {
#       "bookValue": [
#         {
#           "period": "2024-09-28",
#           "v": 56950
#         },
#         {
#           "period": "2023-09-30",
#           "v": 62146
#         },
#         {
#           "period": "2022-09-24",
#           "v": 50672
#         },
#         {
#           "period": "2021-09-25",
#           "v": 63090
#         },
#         {
#           "period": "2020-09-26",
#           "v": 65339
#         },
#         {
#           "period": "2019-09-28",
#           "v": 90488
#         },
#         {
#           "period": "2018-09-29",
#           "v": 107147
#         },
#         {
#           "period": "2017-09-30",
#           "v": 134047
#         },
#         {
#           "period": "2016-09-24",
#           "v": 128249
#         },
#         {
#           "period": "2015-09-26",
#           "v": 119355
#         },
#         {
#           "period": "2014-09-27",
#           "v": 111547
#         },
#         {
#           "period": "2013-09-28",
#           "v": 123549
#         },
#         {
#           "period": "2012-09-29",
#           "v": 118210
#         },
#         {
#           "period": "2011-09-24",
#           "v": 76615
#         },
#         {
#           "period": "2010-09-25",
#           "v": 47791
#         },
#         {
#           "period": "2009-09-26",
#           "v": 31640
#         },
#         {
#           "period": "2008-09-27",
#           "v": 22297
#         },
#         {
#           "period": "2007-09-29",
#           "v": 14532
#         },
#         {
#           "period": "2006-09-30",
#           "v": 9984
#         },
#         {
#           "period": "2005-09-24",
#           "v": 7428
#         },
#         {
#           "period": "2004-09-25",
#           "v": 5076
#         },
#         {
#           "period": "2003-09-27",
#           "v": 4223
#         },
#         {
#           "period": "2002-09-28",
#           "v": 4095
#         },
#         {
#           "period": "2001-09-29",
#           "v": 3920
#         },
#         {
#           "period": "2000-09-30",
#           "v": 4107
#         }
#       ],
#       "cashRatio": [
#         {
#           "period": "2024-09-28",
#           "v": 0.16975259648963673
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.20621713876730807
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.15356340351469652
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.2784485300563432
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.36071049035979963
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.46202160464632325
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.22352474359306126
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.2012518102644474
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2592714477381465
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2620022329735765
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.21819442693229102
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.3266068074579688
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.27881272378184835
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.35091169109760456
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.5434321011485378
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.45741352337910657
#         },
#         {
#           "period": "2008-09-27",
#           "v": 1.045242496259132
#         },
#         {
#           "period": "2007-09-29",
#           "v": 1.0077586206896552
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.9920844327176781
#         },
#         {
#           "period": "2005-09-24",
#           "v": 1.0011471178663607
#         },
#         {
#           "period": "2004-09-25",
#           "v": 1.119954734062618
#         },
#         {
#           "period": "2003-09-27",
#           "v": 1.4408145948239288
#         },
#         {
#           "period": "2002-09-28",
#           "v": 1.3582629674306392
#         },
#         {
#           "period": "2001-09-29",
#           "v": 1.5217391304347827
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.6161407139161924
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.856036152356359
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.9743421052631579
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.6765676567656765
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.7748377433849226
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.3251612903225806
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.6189810754999858
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.2696930127966157
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.3497369380997811
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.49640236933374204
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.3648120110412782
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.48958774321608767
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.4502033024097653
#         },
#         {
#           "period": "1987-09-25",
#           "v": 1.1805305445414247
#         },
#         {
#           "period": "1986-09-26",
#           "v": 1.7538922793614073
#         },
#         {
#           "period": "1985-09-27",
#           "v": 1.1407734619615806
#         }
#       ],
#       "currentRatio": [
#         {
#           "period": "2024-09-28",
#           "v": 0.8673
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.988
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.8794
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.0746
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.3636
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1.5401
#         },
#         {
#           "period": "2018-09-29",
#           "v": 1.1329
#         },
#         {
#           "period": "2017-09-30",
#           "v": 1.2761
#         },
#         {
#           "period": "2016-09-24",
#           "v": 1.3527
#         },
#         {
#           "period": "2015-09-26",
#           "v": 1.1088
#         },
#         {
#           "period": "2014-09-27",
#           "v": 1.0801
#         },
#         {
#           "period": "2013-09-28",
#           "v": 1.6786
#         },
#         {
#           "period": "2012-09-29",
#           "v": 1.4958
#         },
#         {
#           "period": "2011-09-24",
#           "v": 1.6084
#         },
#         {
#           "period": "2010-09-25",
#           "v": 2.0113
#         },
#         {
#           "period": "2009-09-26",
#           "v": 2.7425
#         },
#         {
#           "period": "2008-09-27",
#           "v": 2.6411
#         },
#         {
#           "period": "2007-09-29",
#           "v": 2.3659
#         },
#         {
#           "period": "2006-09-30",
#           "v": 2.2519
#         },
#         {
#           "period": "2005-09-24",
#           "v": 2.9538
#         },
#         {
#           "period": "2004-09-25",
#           "v": 2.6613
#         },
#         {
#           "period": "2003-09-27",
#           "v": 2.4977
#         },
#         {
#           "period": "2002-09-28",
#           "v": 3.2497
#         },
#         {
#           "period": "2001-09-29",
#           "v": 3.388
#         },
#         {
#           "period": "2000-09-30",
#           "v": 2.8076
#         },
#         {
#           "period": "1999-09-25",
#           "v": 2.7663
#         },
#         {
#           "period": "1998-09-25",
#           "v": 2.4329
#         },
#         {
#           "period": "1997-09-26",
#           "v": 1.8834
#         },
#         {
#           "period": "1996-09-27",
#           "v": 2.2541
#         },
#         {
#           "period": "1995-09-29",
#           "v": 2.2469
#         },
#         {
#           "period": "1994-09-30",
#           "v": 2.3023
#         },
#         {
#           "period": "1993-09-24",
#           "v": 1.7297
#         },
#         {
#           "period": "1992-09-25",
#           "v": 2.4962
#         },
#         {
#           "period": "1991-09-27",
#           "v": 2.3529
#         },
#         {
#           "period": "1990-09-28",
#           "v": 2.34
#         },
#         {
#           "period": "1989-09-29",
#           "v": 2.5629
#         },
#         {
#           "period": "1988-09-30",
#           "v": 2.1557
#         },
#         {
#           "period": "1987-09-25",
#           "v": 2.7313
#         },
#         {
#           "period": "1986-09-26",
#           "v": 3.1684
#         },
#         {
#           "period": "1985-09-27",
#           "v": 2.7827
#         }
#       ],
#       "ebitPerShare": [
#         {
#           "period": "2024-09-28",
#           "v": 7.9968
#         },
#         {
#           "period": "2023-09-30",
#           "v": 7.2285
#         },
#         {
#           "period": "2022-09-24",
#           "v": 7.3158
#         },
#         {
#           "period": "2021-09-25",
#           "v": 6.4601
#         },
#         {
#           "period": "2020-09-26",
#           "v": 3.7818
#         },
#         {
#           "period": "2019-09-28",
#           "v": 3.4379
#         },
#         {
#           "period": "2018-09-29",
#           "v": 3.5448
#         },
#         {
#           "period": "2017-09-30",
#           "v": 2.9202
#         },
#         {
#           "period": "2016-09-24",
#           "v": 2.7282
#         },
#         {
#           "period": "2015-09-26",
#           "v": 3.0739
#         },
#         {
#           "period": "2014-09-27",
#           "v": 2.1438
#         },
#         {
#           "period": "2013-09-28",
#           "v": 1.8784
#         },
#         {
#           "period": "2012-09-29",
#           "v": 2.087
#         },
#         {
#           "period": "2011-09-24",
#           "v": 1.2884
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.7101
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.4623
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.3297
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.177
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.0998
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.0685
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0144
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0008
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.0178
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0259
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0184
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.0139
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.0758
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.0998
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0496
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0393
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0083
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0587
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.0332
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0505
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.044
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.0426
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.0252
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.019
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.0074
#         }
#       ],
#       "eps": [
#         {
#           "period": "2024-09-28",
#           "v": 6.0836
#         },
#         {
#           "period": "2023-09-30",
#           "v": 6.1341
#         },
#         {
#           "period": "2022-09-24",
#           "v": 6.1132
#         },
#         {
#           "period": "2021-09-25",
#           "v": 5.614
#         },
#         {
#           "period": "2020-09-26",
#           "v": 3.2753
#         },
#         {
#           "period": "2019-09-28",
#           "v": 2.9714
#         },
#         {
#           "period": "2018-09-29",
#           "v": 2.9765
#         },
#         {
#           "period": "2017-09-30",
#           "v": 2.3017
#         },
#         {
#           "period": "2016-09-24",
#           "v": 2.0766
#         },
#         {
#           "period": "2015-09-26",
#           "v": 2.3042
#         },
#         {
#           "period": "2014-09-27",
#           "v": 1.6133
#         },
#         {
#           "period": "2013-09-28",
#           "v": 1.4198
#         },
#         {
#           "period": "2012-09-29",
#           "v": 1.5767
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.9884
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.5412
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.3243
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.2422
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.1404
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.0809
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.0554
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0123
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0034
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0032
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.0013
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.039
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0308
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.0164
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.074
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.0589
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0308
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0233
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0065
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0387
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.023
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0337
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.0315
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.0275
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.0148
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.0107
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.0044
#         }
#       ],
#       "ev": [
#         {
#           "period": "2024-09-28",
#           "v": 3599793.2
#         },
#         {
#           "period": "2023-09-30",
#           "v": 2783970
#         },
#         {
#           "period": "2022-09-24",
#           "v": 2501154.2
#         },
#         {
#           "period": "2021-09-25",
#           "v": 2493617
#         },
#         {
#           "period": "2020-09-26",
#           "v": 2041191
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1071363
#         },
#         {
#           "period": "2018-09-29",
#           "v": 1186220
#         },
#         {
#           "period": "2017-09-30",
#           "v": 889855
#         },
#         {
#           "period": "2016-09-24",
#           "v": 674795
#         },
#         {
#           "period": "2015-09-26",
#           "v": 670483
#         },
#         {
#           "period": "2014-09-27",
#           "v": 608712
#         },
#         {
#           "period": "2013-09-28",
#           "v": 435827
#         },
#         {
#           "period": "2012-09-29",
#           "v": 607370
#         },
#         {
#           "period": "2011-09-24",
#           "v": 364842
#         },
#         {
#           "period": "2010-09-25",
#           "v": 254736
#         },
#         {
#           "period": "2009-09-26",
#           "v": 161495
#         },
#         {
#           "period": "2008-09-27",
#           "v": 81372.3
#         },
#         {
#           "period": "2007-09-29",
#           "v": 126607
#         },
#         {
#           "period": "2006-09-30",
#           "v": 57277
#         },
#         {
#           "period": "2005-09-24",
#           "v": 41187
#         },
#         {
#           "period": "2004-09-25",
#           "v": 11589.8
#         },
#         {
#           "period": "2003-09-27",
#           "v": 4629.27
#         },
#         {
#           "period": "2002-09-28",
#           "v": 3267.85
#         },
#         {
#           "period": "2001-09-29",
#           "v": 3384.29
#         },
#         {
#           "period": "2000-09-30",
#           "v": 6989.5
#         }
#       ],
#       "fcfMargin": [
#         {
#           "period": "2024-09-28",
#           "v": 0.2783
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.2598
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.2826
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.2541
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.2673
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2264
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.2414
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.2259
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2481
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2986
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.273
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.2609
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.2649
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.2779
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.2526
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.2085
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.224
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.1824
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.0809
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.1633
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0916
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0201
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0909
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.1224
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.121
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.0347
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0628
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.1025
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.1331
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.0508
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.037
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.0383
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.1307
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.1099
#         }
#       ],
#       "grossMargin": [
#         {
#           "period": "2024-09-28",
#           "v": 0.4621
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.4413
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.4331
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.4178
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.3823
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.3782
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.3834
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.3847
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.3908
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.4006
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.3859
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.3762
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.4387
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.4048
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.3938
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.4014
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.352
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.3317
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.2898
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.2901
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.2726
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.2752
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.2792
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.2303
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.2713
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.2765
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.2489
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.1932
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.0984
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.2584
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.2551
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.342
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.4368
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.4747
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.5311
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.49
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0.511
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0.5129
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0.5315
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0.4173
#         }
#       ],
#       "inventoryTurnover": [
#         {
#           "period": "2024-09-28",
#           "v": 30.8955
#         },
#         {
#           "period": "2023-09-30",
#           "v": 37.9777
#         },
#         {
#           "period": "2022-09-24",
#           "v": 38.7899
#         },
#         {
#           "period": "2021-09-25",
#           "v": 40.0303
#         },
#         {
#           "period": "2020-09-26",
#           "v": 41.523
#         },
#         {
#           "period": "2019-09-28",
#           "v": 40.1345
#         },
#         {
#           "period": "2018-09-29",
#           "v": 37.1708
#         },
#         {
#           "period": "2017-09-30",
#           "v": 40.3744
#         },
#         {
#           "period": "2016-09-24",
#           "v": 58.6369
#         },
#         {
#           "period": "2015-09-26",
#           "v": 62.8202
#         },
#         {
#           "period": "2014-09-27",
#           "v": 57.9396
#         },
#         {
#           "period": "2013-09-28",
#           "v": 83.4489
#         },
#         {
#           "period": "2012-09-29",
#           "v": 112.12
#         },
#         {
#           "period": "2011-09-24",
#           "v": 70.532
#         },
#         {
#           "period": "2010-09-25",
#           "v": 52.5113
#         },
#         {
#           "period": "2009-09-26",
#           "v": 53.2842
#         },
#         {
#           "period": "2008-09-27",
#           "v": 56.8281
#         },
#         {
#           "period": "2007-09-29",
#           "v": 53.3312
#         },
#         {
#           "period": "2006-09-30",
#           "v": 63.0667
#         },
#         {
#           "period": "2005-09-24",
#           "v": 74.3534
#         },
#         {
#           "period": "2004-09-25",
#           "v": 76.7134
#         },
#         {
#           "period": "2003-09-27",
#           "v": 89.0891
#         },
#         {
#           "period": "2002-09-28",
#           "v": 147.8214
#         },
#         {
#           "period": "2001-09-29",
#           "v": 187.6364
#         },
#         {
#           "period": "2000-09-30",
#           "v": 219.5094
#         },
#         {
#           "period": "1999-09-25",
#           "v": 90.5714
#         },
#         {
#           "period": "1998-09-25",
#           "v": 17.3282
#         },
#         {
#           "period": "1997-09-26",
#           "v": 10.3967
#         },
#         {
#           "period": "1996-09-27",
#           "v": 7.2753
#         },
#         {
#           "period": "1995-09-29",
#           "v": 5.7302
#         },
#         {
#           "period": "1994-09-30",
#           "v": 5.2753
#         },
#         {
#           "period": "1993-09-24",
#           "v": 5.0307
#         },
#         {
#           "period": "1992-09-25",
#           "v": 6.3772
#         },
#         {
#           "period": "1991-09-27",
#           "v": 6.4532
#         },
#         {
#           "period": "1990-09-28",
#           "v": 6.2736
#         },
#         {
#           "period": "1989-09-29",
#           "v": 9.5546
#         },
#         {
#           "period": "1988-09-30",
#           "v": 12.662
#         }
#       ],
#       "longtermDebtTotalAsset": [
#         {
#           "period": "2024-09-28",
#           "v": 0.2349
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.2702
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.2805
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.3108
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.3046
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2712
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.2563
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.259
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2345
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.1837
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.125
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.0819
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0502
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0526
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0441
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0581
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.2224
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.2247
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.1769
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0486
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0574
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0014
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0
#         }
#       ],
#       "longtermDebtTotalCapital": [
#         {
#           "period": "2024-09-28",
#           "v": 0.5214
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.5468
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.5764
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.5783
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.553
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.4624
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.4229
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.3893
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.3504
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2903
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.1974
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.1207
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0716
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0748
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0681
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0881
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.3675
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.437
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.2972
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0827
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.1022
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0025
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0
#         }
#       ],
#       "longtermDebtTotalEquity": [
#         {
#           "period": "2024-09-28",
#           "v": 1.5057
#         },
#         {
#           "period": "2023-09-30",
#           "v": 1.5332
#         },
#         {
#           "period": "2022-09-24",
#           "v": 1.9529
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.7294
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.5101
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1.0146
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.8748
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.7252
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.5881
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.4468
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.2599
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.1373
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0772
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0809
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.073
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0966
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.581
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.7925
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.4611
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.1044
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.1278
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0035
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0
#         },
#         {
#           "period": "1988-09-30",
#           "v": 0
#         },
#         {
#           "period": "1987-09-25",
#           "v": 0
#         },
#         {
#           "period": "1986-09-26",
#           "v": 0
#         },
#         {
#           "period": "1985-09-27",
#           "v": 0
#         }
#       ],
#       "netDebtToTotalCapital": [
#         {
#           "period": "2024-09-28",
#           "v": 0.4717
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.4714
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.5671
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.4804
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.4208
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2982
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.3996
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.382
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.3091
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2352
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.1461
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.0192
#         },
#         {
#           "period": "2012-09-29",
#           "v": -0.0909
#         },
#         {
#           "period": "2011-09-24",
#           "v": -0.1281
#         },
#         {
#           "period": "2010-09-25",
#           "v": -0.2356
#         },
#         {
#           "period": "2009-09-26",
#           "v": -0.1663
#         },
#         {
#           "period": "2008-09-27",
#           "v": -0.5326
#         },
#         {
#           "period": "2007-09-29",
#           "v": -0.6435
#         },
#         {
#           "period": "2006-09-30",
#           "v": -0.6402
#         },
#         {
#           "period": "2005-09-24",
#           "v": -0.47
#         },
#         {
#           "period": "2004-09-25",
#           "v": -0.5849
#         },
#         {
#           "period": "2003-09-27",
#           "v": -0.683
#         },
#         {
#           "period": "2002-09-28",
#           "v": -0.4389
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.4704
#         },
#         {
#           "period": "2000-09-30",
#           "v": -0.2022
#         },
#         {
#           "period": "1999-09-25",
#           "v": -0.3014
#         },
#         {
#           "period": "1998-09-25",
#           "v": -0.203
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.1167
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.1306
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0022
#         },
#         {
#           "period": "1994-09-30",
#           "v": -0.2036
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0539
#         },
#         {
#           "period": "1992-09-25",
#           "v": -0.1324
#         },
#         {
#           "period": "1991-09-27",
#           "v": -0.2379
#         },
#         {
#           "period": "1990-09-28",
#           "v": -0.1606
#         },
#         {
#           "period": "1989-09-29",
#           "v": -0.2474
#         },
#         {
#           "period": "1988-09-30",
#           "v": -0.0438
#         },
#         {
#           "period": "1987-09-25",
#           "v": -0.6756
#         },
#         {
#           "period": "1986-09-26",
#           "v": -0.8302
#         },
#         {
#           "period": "1985-09-27",
#           "v": -0.6122
#         }
#       ],
#       "netDebtToTotalEquity": [
#         {
#           "period": "2024-09-28",
#           "v": 1.3623
#         },
#         {
#           "period": "2023-09-30",
#           "v": 1.3218
#         },
#         {
#           "period": "2022-09-24",
#           "v": 1.9215
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.4365
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.1491
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.6543
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.8266
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.7116
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.5189
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.362
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.1923
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.0219
#         },
#         {
#           "period": "2012-09-29",
#           "v": -0.0909
#         },
#         {
#           "period": "2011-09-24",
#           "v": -0.1281
#         },
#         {
#           "period": "2010-09-25",
#           "v": -0.2356
#         },
#         {
#           "period": "2009-09-26",
#           "v": -0.1663
#         },
#         {
#           "period": "2008-09-27",
#           "v": -0.5326
#         },
#         {
#           "period": "2007-09-29",
#           "v": -0.6435
#         },
#         {
#           "period": "2006-09-30",
#           "v": -0.6402
#         },
#         {
#           "period": "2005-09-24",
#           "v": -0.47
#         },
#         {
#           "period": "2004-09-25",
#           "v": -0.5849
#         },
#         {
#           "period": "2003-09-27",
#           "v": -0.7322
#         },
#         {
#           "period": "2002-09-28",
#           "v": -0.4728
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.5084
#         },
#         {
#           "period": "2000-09-30",
#           "v": -0.2169
#         },
#         {
#           "period": "1999-09-25",
#           "v": -0.3305
#         },
#         {
#           "period": "1998-09-25",
#           "v": -0.321
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.2117
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.2026
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0028
#         },
#         {
#           "period": "1994-09-30",
#           "v": -0.2546
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0759
#         },
#         {
#           "period": "1992-09-25",
#           "v": -0.1436
#         },
#         {
#           "period": "1991-09-27",
#           "v": -0.2579
#         },
#         {
#           "period": "1990-09-28",
#           "v": -0.1742
#         },
#         {
#           "period": "1989-09-29",
#           "v": -0.2568
#         },
#         {
#           "period": "1988-09-30",
#           "v": -0.0575
#         },
#         {
#           "period": "1987-09-25",
#           "v": -0.6756
#         },
#         {
#           "period": "1986-09-26",
#           "v": -0.8302
#         },
#         {
#           "period": "1985-09-27",
#           "v": -0.6122
#         }
#       ],
#       "netMargin": [
#         {
#           "period": "2024-09-28",
#           "v": 0.2397
#         },
#         {
#           "period": "2023-09-30",
#           "v": 0.2531
#         },
#         {
#           "period": "2022-09-24",
#           "v": 0.2531
#         },
#         {
#           "period": "2021-09-25",
#           "v": 0.2588
#         },
#         {
#           "period": "2020-09-26",
#           "v": 0.2091
#         },
#         {
#           "period": "2019-09-28",
#           "v": 0.2124
#         },
#         {
#           "period": "2018-09-29",
#           "v": 0.2241
#         },
#         {
#           "period": "2017-09-30",
#           "v": 0.2109
#         },
#         {
#           "period": "2016-09-24",
#           "v": 0.2119
#         },
#         {
#           "period": "2015-09-26",
#           "v": 0.2285
#         },
#         {
#           "period": "2014-09-27",
#           "v": 0.2161
#         },
#         {
#           "period": "2013-09-28",
#           "v": 0.2167
#         },
#         {
#           "period": "2012-09-29",
#           "v": 0.2667
#         },
#         {
#           "period": "2011-09-24",
#           "v": 0.2395
#         },
#         {
#           "period": "2010-09-25",
#           "v": 0.2148
#         },
#         {
#           "period": "2009-09-26",
#           "v": 0.1919
#         },
#         {
#           "period": "2008-09-27",
#           "v": 0.1632
#         },
#         {
#           "period": "2007-09-29",
#           "v": 0.1422
#         },
#         {
#           "period": "2006-09-30",
#           "v": 0.103
#         },
#         {
#           "period": "2005-09-24",
#           "v": 0.0953
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0.0321
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0111
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0113
#         },
#         {
#           "period": "2001-09-29",
#           "v": -0.0047
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0985
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.098
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.052
#         },
#         {
#           "period": "1997-09-26",
#           "v": -0.1476
#         },
#         {
#           "period": "1996-09-27",
#           "v": -0.083
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.0383
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.0338
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.0109
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0748
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.0491
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0854
#         },
#         {
# ...
#           "v": 0
#         },
#         {
#           "period": "2005-06-25",
#           "v": 0
#         },
#         {
#           "period": "2005-03-26",
#           "v": 0
#         },
#         {
#           "period": "2004-12-25",
#           "v": 0
#         },
#         {
#           "period": "2004-09-25",
#           "v": 0
#         },
#         {
#           "period": "2004-06-26",
#           "v": 0
#         },
#         {
#           "period": "2004-03-27",
#           "v": 0
#         },
#         {
#           "period": "2003-12-27",
#           "v": 0.0652
#         },
#         {
#           "period": "2003-09-27",
#           "v": 0.0672
#         },
#         {
#           "period": "2003-06-28",
#           "v": 0.0681
#         },
#         {
#           "period": "2003-03-29",
#           "v": 0.0697
#         },
#         {
#           "period": "2002-12-28",
#           "v": 0.0721
#         },
#         {
#           "period": "2002-09-28",
#           "v": 0.0716
#         },
#         {
#           "period": "2002-06-29",
#           "v": 0.0721
#         },
#         {
#           "period": "2002-03-30",
#           "v": 0.0719
#         },
#         {
#           "period": "2001-12-29",
#           "v": 0.0736
#         },
#         {
#           "period": "2001-09-29",
#           "v": 0.0748
#         },
#         {
#           "period": "2001-06-30",
#           "v": 0.0759
#         },
#         {
#           "period": "2001-03-31",
#           "v": 0.0782
#         },
#         {
#           "period": "2000-12-30",
#           "v": 0.0773
#         },
#         {
#           "period": "2000-09-30",
#           "v": 0.0681
#         },
#         {
#           "period": "2000-07-01",
#           "v": 0.067
#         },
#         {
#           "period": "2000-04-01",
#           "v": 0.0664
#         },
#         {
#           "period": "2000-01-01",
#           "v": 0.0636
#         },
#         {
#           "period": "1999-09-25",
#           "v": 0.0881
#         },
#         {
#           "period": "1999-06-26",
#           "v": 0.0917
#         },
#         {
#           "period": "1999-03-27",
#           "v": 0.3051
#         },
#         {
#           "period": "1998-12-26",
#           "v": 0.3316
#         },
#         {
#           "period": "1998-09-25",
#           "v": 0.3675
#         },
#         {
#           "period": "1998-06-26",
#           "v": 0.3907
#         },
#         {
#           "period": "1998-03-27",
#           "v": 0.4129
#         },
#         {
#           "period": "1997-12-26",
#           "v": 0.4396
#         },
#         {
#           "period": "1997-09-26",
#           "v": 0.4485
#         },
#         {
#           "period": "1997-06-27",
#           "v": 0.4741
#         },
#         {
#           "period": "1997-03-28",
#           "v": 0.4663
#         },
#         {
#           "period": "1996-12-27",
#           "v": 0.3678
#         },
#         {
#           "period": "1996-09-27",
#           "v": 0.3555
#         },
#         {
#           "period": "1996-06-28",
#           "v": 0.3599
#         },
#         {
#           "period": "1996-03-29",
#           "v": 0.2416
#         },
#         {
#           "period": "1995-12-29",
#           "v": 0.223
#         },
#         {
#           "period": "1995-09-29",
#           "v": 0.2085
#         },
#         {
#           "period": "1995-06-30",
#           "v": 0.2005
#         },
#         {
#           "period": "1995-03-31",
#           "v": 0.2554
#         },
#         {
#           "period": "1994-12-30",
#           "v": 0.1668
#         },
#         {
#           "period": "1994-09-30",
#           "v": 0.2002
#         },
#         {
#           "period": "1994-07-01",
#           "v": 0.2676
#         },
#         {
#           "period": "1994-04-01",
#           "v": 0.2739
#         },
#         {
#           "period": "1993-12-31",
#           "v": 0.2681
#         },
#         {
#           "period": "1993-09-24",
#           "v": 0.2907
#         },
#         {
#           "period": "1993-06-25",
#           "v": 0.1323
#         },
#         {
#           "period": "1993-03-26",
#           "v": 0.0255
#         },
#         {
#           "period": "1992-12-25",
#           "v": 0.0771
#         },
#         {
#           "period": "1992-09-25",
#           "v": 0.0778
#         },
#         {
#           "period": "1992-06-26",
#           "v": 0.0783
#         },
#         {
#           "period": "1992-03-27",
#           "v": 0.0613
#         },
#         {
#           "period": "1991-12-27",
#           "v": 0.0232
#         },
#         {
#           "period": "1991-09-27",
#           "v": 0.0776
#         },
#         {
#           "period": "1991-06-28",
#           "v": 0.0858
#         },
#         {
#           "period": "1991-03-29",
#           "v": 0.0033
#         },
#         {
#           "period": "1990-12-28",
#           "v": 0.0147
#         },
#         {
#           "period": "1990-09-28",
#           "v": 0.0781
#         },
#         {
#           "period": "1990-06-29",
#           "v": 0.0163
#         },
#         {
#           "period": "1990-03-30",
#           "v": 0.0127
#         },
#         {
#           "period": "1989-12-29",
#           "v": 0.0427
#         },
#         {
#           "period": "1989-09-29",
#           "v": 0.0368
#         }
#       ],
#       "totalRatio": [
#         {
#           "period": "2025-03-29",
#           "v": 1.2526
#         },
#         {
#           "period": "2024-12-28",
#           "v": 1.2407
#         },
#         {
#           "period": "2024-09-28",
#           "v": 1.1849
#         },
#         {
#           "period": "2024-06-29",
#           "v": 1.2518
#         },
#         {
#           "period": "2024-03-30",
#           "v": 1.2819
#         },
#         {
#           "period": "2023-12-30",
#           "v": 1.2652
#         },
#         {
#           "period": "2023-09-30",
#           "v": 1.214
#         },
#         {
#           "period": "2023-07-01",
#           "v": 1.2194
#         },
#         {
#           "period": "2023-04-01",
#           "v": 1.2302
#         },
#         {
#           "period": "2022-12-31",
#           "v": 1.1956
#         },
#         {
#           "period": "2022-09-24",
#           "v": 1.1677
#         },
#         {
#           "period": "2022-06-25",
#           "v": 1.2089
#         },
#         {
#           "period": "2022-03-26",
#           "v": 1.2379
#         },
#         {
#           "period": "2021-12-25",
#           "v": 1.2326
#         },
#         {
#           "period": "2021-09-25",
#           "v": 1.2191
#         },
#         {
#           "period": "2021-06-26",
#           "v": 1.2421
#         },
#         {
#           "period": "2021-03-27",
#           "v": 1.2581
#         },
#         {
#           "period": "2020-12-26",
#           "v": 1.2301
#         },
#         {
#           "period": "2020-09-26",
#           "v": 1.2527
#         },
#         {
#           "period": "2020-06-27",
#           "v": 1.295
#         },
#         {
#           "period": "2020-03-28",
#           "v": 1.3241
#         },
#         {
#           "period": "2019-12-28",
#           "v": 1.3566
#         },
#         {
#           "period": "2019-09-28",
#           "v": 1.3648
#         },
#         {
#           "period": "2019-06-29",
#           "v": 1.4272
#         },
#         {
#           "period": "2019-03-30",
#           "v": 1.4483
#         },
#         {
#           "period": "2018-12-29",
#           "v": 1.4608
#         },
#         {
#           "period": "2018-09-29",
#           "v": 1.4144
#         },
#         {
#           "period": "2018-06-30",
#           "v": 1.4907
#         },
#         {
#           "period": "2018-03-31",
#           "v": 1.5273
#         },
#         {
#           "period": "2017-12-30",
#           "v": 1.5259
#         },
#         {
#           "period": "2017-09-30",
#           "v": 1.5556
#         },
#         {
#           "period": "2017-07-01",
#           "v": 1.6225
#         },
#         {
#           "period": "2017-04-01",
#           "v": 1.6689
#         },
#         {
#           "period": "2016-12-31",
#           "v": 1.6661
#         },
#         {
#           "period": "2016-09-24",
#           "v": 1.663
#         },
#         {
#           "period": "2016-06-25",
#           "v": 1.7067
#         },
#         {
#           "period": "2016-03-26",
#           "v": 1.7462
#         },
#         {
#           "period": "2015-12-26",
#           "v": 1.7773
#         },
#         {
#           "period": "2015-09-26",
#           "v": 1.698
#         },
#         {
#           "period": "2015-06-27",
#           "v": 1.8522
#         },
#         {
#           "period": "2015-03-28",
#           "v": 1.9759
#         },
#         {
#           "period": "2014-12-27",
#           "v": 1.89
#         },
#         {
#           "period": "2014-09-27",
#           "v": 1.9273
#         },
#         {
#           "period": "2014-06-28",
#           "v": 2.1906
#         },
#         {
#           "period": "2014-03-29",
#           "v": 2.4005
#         },
#         {
#           "period": "2013-12-28",
#           "v": 2.3579
#         },
#         {
#           "period": "2013-09-28",
#           "v": 2.4805
#         },
#         {
#           "period": "2013-06-29",
#           "v": 2.6124
#         },
#         {
#           "period": "2013-03-30",
#           "v": 3.2866
#         },
#         {
#           "period": "2012-12-29",
#           "v": 2.8525
#         },
#         {
#           "period": "2012-09-29",
#           "v": 3.0432
#         },
#         {
#           "period": "2012-06-30",
#           "v": 3.1847
#         },
#         {
#           "period": "2012-03-31",
#           "v": 3.1162
#         },
#         {
#           "period": "2011-12-31",
#           "v": 2.8519
#         },
#         {
#           "period": "2011-09-24",
#           "v": 2.9271
#         },
#         {
#           "period": "2011-06-25",
#           "v": 2.8533
#         },
#         {
#           "period": "2011-03-26",
#           "v": 2.8391
#         },
#         {
#           "period": "2010-12-25",
#           "v": 2.7043
#         },
#         {
#           "period": "2010-09-25",
#           "v": 2.7447
#         },
#         {
#           "period": "2010-06-26",
#           "v": 2.9946
#         },
#         {
#           "period": "2010-03-27",
#           "v": 3.2219
#         },
#         {
#           "period": "2009-12-26",
#           "v": 2.9698
#         },
#         {
#           "period": "2009-09-26",
#           "v": 2.9948
#         },
#         {
#           "period": "2009-06-27",
#           "v": 2.1634
#         },
#         {
#           "period": "2009-03-28",
#           "v": 2.2845
#         },
#         {
#           "period": "2008-12-27",
#           "v": 2.1525
#         },
#         {
#           "period": "2008-09-27",
#           "v": 2.6071
#         },
#         {
#           "period": "2008-06-28",
#           "v": 2.6234
#         },
#         {
#           "period": "2008-03-29",
#           "v": 2.4538
#         },
#         {
#           "period": "2007-12-29",
#           "v": 2.2697
#         },
#         {
#           "period": "2007-09-29",
#           "v": 2.3437
#         },
#         {
#           "period": "2007-06-30",
#           "v": 2.6261
#         },
#         {
#           "period": "2007-03-31",
#           "v": 2.9009
#         },
#         {
#           "period": "2006-12-30",
#           "v": 2.3638
#         },
#         {
#           "period": "2006-09-30",
#           "v": 2.3826
#         },
#         {
#           "period": "2006-07-01",
#           "v": 2.6131
#         },
#         {
#           "period": "2006-04-01",
#           "v": 2.6604
#         },
#         {
#           "period": "2005-12-31",
#           "v": 2.4446
#         },
#         {
#           "period": "2005-09-24",
#           "v": 2.817
#         },
#         {
#           "period": "2005-06-25",
#           "v": 2.8601
#         },
#         {
#           "period": "2005-03-26",
#           "v": 2.7144
#         },
#         {
#           "period": "2004-12-25",
#           "v": 2.6209
#         },
#         {
#           "period": "2004-09-25",
#           "v": 2.7068
#         },
#         {
#           "period": "2004-06-26",
#           "v": 2.9959
#         },
#         {
#           "period": "2004-03-27",
#           "v": 3
#         },
#         {
#           "period": "2003-12-27",
#           "v": 2.6395
#         },
#         {
#           "period": "2003-09-27",
#           "v": 2.6292
#         },
#         {
#           "period": "2003-06-28",
#           "v": 2.8716
#         },
#         {
#           "period": "2003-03-29",
#           "v": 2.8627
#         },
#         {
#           "period": "2002-12-28",
#           "v": 2.9118
#         },
#         {
#           "period": "2002-09-28",
#           "v": 2.8588
#         },
#         {
#           "period": "2002-06-29",
#           "v": 2.8258
#         },
#         {
#           "period": "2002-03-30",
#           "v": 2.784
#         },
#         {
#           "period": "2001-12-29",
#           "v": 2.8395
#         },
#         {
#           "period": "2001-09-29",
#           "v": 2.8658
#         },
#         {
#           "period": "2001-06-30",
#           "v": 2.7433
#         },
#         {
#           "period": "2001-03-31",
#           "v": 2.5627
#         },
#         {
#           "period": "2000-12-30",
#           "v": 2.6324
#         },
#         {
#           "period": "2000-09-30",
#           "v": 2.5234
#         },
#         {
#           "period": "2000-07-01",
#           "v": 2.5152
#         },
#         {
#           "period": "2000-04-01",
#           "v": 2.5097
#         },
#         {
#           "period": "2000-01-01",
#           "v": 2.3916
#         },
#         {
#           "period": "1999-09-25",
#           "v": 2.509
#         },
#         {
#           "period": "1999-06-26",
#           "v": 2.4495
#         },
#         {
#           "period": "1999-03-27",
#           "v": 1.788
#         },
#         {
#           "period": "1998-12-26",
#           "v": 1.7205
#         },
#         {
#           "period": "1998-09-25",
#           "v": 1.6203
#         },
#         {
#           "period": "1998-06-26",
#           "v": 1.5816
#         },
#         {
#           "period": "1998-03-27",
#           "v": 1.539
#         },
#         {
#           "period": "1997-12-26",
#           "v": 1.4316
#         },
#         {
#           "period": "1997-09-26",
#           "v": 1.3956
#         },
#         {
#           "period": "1997-06-27",
#           "v": 1.3803
#         },
#         {
#           "period": "1997-03-28",
#           "v": 1.3827
#         },
#         {
#           "period": "1996-12-27",
#           "v": 1.5832
#         },
#         {
#           "period": "1996-09-27",
#           "v": 1.6225
#         },
#         {
#           "period": "1996-06-28",
#           "v": 1.6075
#         },
#         {
#           "period": "1996-03-29",
#           "v": 1.6469
#         },
#         {
#           "period": "1995-12-29",
#           "v": 1.7433
#         },
#         {
#           "period": "1995-09-29",
#           "v": 1.8712
#         },
#         {
#           "period": "1995-06-30",
#           "v": 1.8611
#         },
#         {
#           "period": "1995-03-31",
#           "v": 1.8135
#         },
#         {
#           "period": "1994-12-30",
#           "v": 1.8623
#         },
#         {
#           "period": "1994-09-30",
#           "v": 1.8164
#         },
#         {
#           "period": "1994-07-01",
#           "v": 1.78
#         },
#         {
#           "period": "1994-04-01",
#           "v": 1.6639
#         },
#         {
#           "period": "1993-12-31",
#           "v": 1.6869
#         },
#         {
#           "period": "1993-09-24",
#           "v": 1.6443
#         },
#         {
#           "period": "1993-06-25",
#           "v": 1.7354
#         },
#         {
#           "period": "1993-03-26",
#           "v": 2.0469
#         },
#         {
#           "period": "1992-12-25",
#           "v": 2.0321
#         },
#         {
#           "period": "1992-09-25",
#           "v": 2.0742
#         },
#         {
#           "period": "1992-06-26",
#           "v": 2.0608
#         },
#         {
#           "period": "1992-03-27",
#           "v": 2.1257
#         },
#         {
#           "period": "1991-12-27",
#           "v": 2.0549
#         },
#         {
#           "period": "1991-09-27",
#           "v": 2.023
#         },
#         {
#           "period": "1991-06-28",
#           "v": 1.9314
#         },
#         {
#           "period": "1991-03-29",
#           "v": 2.1285
#         },
#         {
#           "period": "1990-12-28",
#           "v": 1.9584
#         },
#         {
#           "period": "1990-09-28",
#           "v": 1.9463
#         },
#         {
#           "period": "1990-06-29",
#           "v": 2.0898
#         },
#         {
#           "period": "1990-03-30",
#           "v": 2.2663
#         },
#         {
#           "period": "1989-12-29",
#           "v": 2.1817
#         },
#         {
#           "period": "1989-09-29",
#           "v": 2.1809
#         }
#       ]
#     }
#   },
#   "symbol": "AAPL"
# }

# %% [markdown]
# ### 2. `yfinance_utils`
#
# 这里面给Agent注册的工具只有`get_stock_data(...)`
#
# - `get_stock_data(...)`: 获取指定股票代码 (`symbol`) 在给定开始日期 (`start_date`) 和结束日期 (`end_date`) 之间的历史股价数据。返回一个包含股价数据的 `DataFrame`.
#
# - `get_stock_info(...)`: 获取股票的最新信息。返回包含股票信息的字典。
#
# - `get_company_info(...)`: 获取并返回公司的基本信息（如公司名、行业、国家等）到一个 `DataFrame`
#
# - `get_stock_dividends(...)`: 获取并返回最新的股息数据。返回一个包含股息数据的 `DataFrame`。
#
# - `get_income_stmt(...)`: 获取并返回公司最新的利润表. 返回一个包含利润表数据的 `DataFrame`
#
# - `get_balance_sheet(...)`: 获取并返回公司最新的资产负债表. 返回一个包含资产负债表数据的 `DataFrame`
#
# - `get_cash_flow(...)`: 获取并返回公司最新的现金流量表. 返回一个包含现金流量表数据的 `DataFrame`
#
# - `get_analyst_recommendations(...)`: 获取最新的分析师评级建议。返回一个tuple，包含最常见的建议（字符串）和它的票数（整数）。如果无建议，返回 (None, 0)。

# %% [markdown]
# #### `get_stock_data`

# %%
YFinanceUtils.get_stock_data(
    symbol = "AAPL", 
    start_date = "2025-05-01", 
    end_date = "2025-06-02", 
    save_path = "./AAPL_news.csv"
)
# Out:
# Stock data for AAPL saved to ./AAPL_news.csv
#                                  Open        High         Low       Close  \
# Date
# 2025-05-01 00:00:00-04:00  208.806182  214.279000  208.626409  213.040634
# 2025-05-02 00:00:00-04:00  205.820091  206.718922  201.895245  205.081070
# 2025-05-05 00:00:00-04:00  202.834025  203.832716  197.950430  198.629532
# 2025-05-06 00:00:00-04:00  197.950420  200.387212  196.761976  198.250015
# 2025-05-07 00:00:00-04:00  198.909155  199.178806  192.996910  195.992981
# 2025-05-08 00:00:00-04:00  197.461064  199.788014  194.425036  197.231369
# 2025-05-09 00:00:00-04:00  198.739390  200.277366  197.281295  198.270004
# 2025-05-12 00:00:00-04:00  210.970001  211.270004  206.750000  210.789993
# 2025-05-13 00:00:00-04:00  210.429993  213.399994  209.000000  212.929993
# 2025-05-14 00:00:00-04:00  212.429993  213.940002  210.580002  212.330002
# 2025-05-15 00:00:00-04:00  210.949997  212.960007  209.539993  211.449997
# 2025-05-16 00:00:00-04:00  212.360001  212.570007  209.770004  211.259995
# 2025-05-19 00:00:00-04:00  207.910004  209.479996  204.259995  208.779999
# 2025-05-20 00:00:00-04:00  207.669998  208.470001  205.029999  206.860001
# 2025-05-21 00:00:00-04:00  205.169998  207.039993  200.710007  202.089996
# 2025-05-22 00:00:00-04:00  200.710007  202.750000  199.699997  201.360001
# 2025-05-23 00:00:00-04:00  193.669998  197.699997  193.460007  195.270004
# 2025-05-27 00:00:00-04:00  198.300003  200.740005  197.429993  200.210007
# 2025-05-28 00:00:00-04:00  200.589996  202.729996  199.899994  200.419998
# 2025-05-29 00:00:00-04:00  203.580002  203.809998  198.509995  199.949997
# 2025-05-30 00:00:00-04:00  199.369995  201.960007  196.779999  200.850006
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-05-01 00:00:00-04:00   57365700       0.00           0.0
# 2025-05-02 00:00:00-04:00  101010600       0.00           0.0
# 2025-05-05 00:00:00-04:00   69018500       0.00           0.0
# 2025-05-06 00:00:00-04:00   51216500       0.00           0.0
# 2025-05-07 00:00:00-04:00   68536700       0.00           0.0
# 2025-05-08 00:00:00-04:00   50478900       0.00           0.0
# 2025-05-09 00:00:00-04:00   36453900       0.00           0.0
# 2025-05-12 00:00:00-04:00   63775800       0.26           0.0
# 2025-05-13 00:00:00-04:00   51909300       0.00           0.0
# 2025-05-14 00:00:00-04:00   49325800       0.00           0.0
# 2025-05-15 00:00:00-04:00   45029500       0.00           0.0
# 2025-05-16 00:00:00-04:00   54737900       0.00           0.0
# 2025-05-19 00:00:00-04:00   46140500       0.00           0.0
# 2025-05-20 00:00:00-04:00   42496600       0.00           0.0
# 2025-05-21 00:00:00-04:00   59211800       0.00           0.0
# 2025-05-22 00:00:00-04:00   46742400       0.00           0.0
# 2025-05-23 00:00:00-04:00   78432900       0.00           0.0
# 2025-05-27 00:00:00-04:00   56288500       0.00           0.0
# 2025-05-28 00:00:00-04:00   45339700       0.00           0.0
# 2025-05-29 00:00:00-04:00   51396800       0.00           0.0
# 2025-05-30 00:00:00-04:00   70753100       0.00           0.0

# %%
YFinanceUtils.get_analyst_recommendations("AAPL")
# Out:
# ('buy', 20)
